# %% [markdown]
# # Cours 7 : interface graphique avec tkinter
#
# **GUI = graphical user interface**

# %% [markdown]
# ## 1. Généralités sur la programmation avec tkinter
# ---
#
# *tkinter = tk interface*
#
# *tk = tool kit* est une bibliothèque d'interface graphique commune à différents langages de programmation.
#
# tkinter est installé avec Python. Il existe d'autres librairies graphiques comme *pygame*.
#
# **Sites de référence:**
#
# [Tutoriel simple en français](https://openclassrooms.com/fr/courses/235344-apprenez-a-programmer-en-python/234859-creez-des-interfaces-graphiques-avec-tkinter)
#
# [Tutoriel plus avancé en français](https://vincent.developpez.com/cours-tutoriels/python/tkinter/apprendre-creer-interface-graphique-tkinter-python-3/#LI)
#
# [Pour retrouver rapidement des informations sur tkinter](http://tkinter.fdex.eu/) (site très utile!)
#
# [La documentation officielle de Python](https://docs.python.org/fr/3/library/tkinter.html)

# %% [markdown]
# **Eléments d'une interface graphique (aussi appelé IHM = interface homme machine)**
#
# ---
#
# * fenêtre graphique
#
# * *widgets* (window gadget): objets graphiques permettant à l'utilisateur d'intéragir avec un programme Python de manière conviviale:
#
#     * affichage de texte ou d'image
#     * boutons
#     * champs de saisie
#     * barre de défilement (aussi appelé ascenseur)
#     * espace de dessin (canevas), etc.
#
#
# * gestionnaire d'événements:
#     * déplacement ou clic de souris
#     * appui sur une touche du clavier
#
# Chaque widget est contenu dans un autre widget, sauf la *fenêtre racine* qui correspond à la fenêtre principale.

# %% [markdown]
# **Elements d'un programme minimal**
#
# ---
#
# * importer la librairie *tkinter* abrégée en `tk`:
# ```python
# import tkinter as tk
# ```
#
# * la fonction de la librairie tkinter `Tk()` créée la fenêtre racine. La valeur retournée par la fonction doit être affecté à une variable pour pouvoir manipuler la fenêtre racine (ajouter des widgets, mettre à jour l'affichage...)
#
# * méthode `.mainloop()` associée à la fenêtre racine qui permet de démarrer le gestionnaire d'événements et de mettre à jour l'affichage. Elle est  toujours placée à la fin du programme (on verra pourquoi plus tard).

# %%
import tkinter as tk


racine = tk.Tk() # Création de la fenêtre racine
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# La fenêtre possède une barre de titre (*tk* par défaut), et un espace gris.
#
# Elle peut être redimensionnée ou fermée avec la souris comme n'importe quelle fenêtre de votre environnement graphique.

# %% [markdown]
# **Créer un widget**
#
# ---
#
# Syntaxe globale:
# ```python
# ma_variable = UnWidget(widget_parent, parametre="une_valeur")
# ```
# * `ma_variable` est le nom choisi pour référencer le widget
# * `UnWidget()` est la fonction qui créée le widget, par exemple:
#     * `Label()`: affichage de texte
#     * `Button()`: bouton à cliquer
#     * `Canvas()`: canevas pour dessiner des objets
# * `widget_parent` est le nom du widget qui va contenir celui qu'on créée
#     * en général ce sera le widget racine pour des petites applications
#     * c'est le premier paramètre de la fonction qui créé le widget
# * les paramètres vont dépendre du widget. Ils sont souvent très nombreux, et on les utilise via leur nom et non pas leur position (sauf pour le widget parent).
# * dans le cours, on ne manipulera qu'une partie minime de la librairie.

# %% [markdown]
# **Exemple**
#
# ---

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
racine.title("Un premier exemple") # ajoute un titre
label = tk.Label(racine, text="Un texte dans ma fenêtre", font=("helvetica", "20")) # création du widget
label.grid() # positionnement du widget
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# En plus de la création du widget, il faut le positionner pour qu'il s'affiche. C'est le rôle de la méthode `.grid()`.
#
# On a également ajouté un titre à la fenêtre.

# %% [markdown]
# ## 2. Positionnement des widgets
#
# ---
#
#
# La librairie tkinter propose trois gestionnaires de position:
# * `.pack()`
# * `.place()`
# * `.grid()`: celui que nous utiliserons

# %% [markdown]
# **Méthode `.grid()`**
#
# ---
#
# Ce gestionnaire place le widget dans une case du widget parent qui est divisé en lignes et colonnes:
#
# ![](grid.png)

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
label1 = tk.Label(racine, text="Un texte long dans ma fenêtre", font = ("helvetica", "30")) # création d'un widget
label2 = tk.Label(racine, text="toto", font = ("helvetica", "30")) # création d'un widget
label1.grid(column=0, row=0) # positionnement du premier widget
label2.grid(row=1, column=0) # positionnement du premier widget
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# Noter que les colonnes croissent de gauche à droite, et les lignes croissent de haut en bas.
#
# L'ensemble des paramètres associés à cette méthode sont [décrits ici](http://tkinter.fdex.eu/doc/gp.html).

# %% [markdown]
# Tester différentes valeurs de colonnes et lignes.

# %% [markdown]
# **Ajouter des marges**
#
# ---
#
# Avec les paramètres `padx` et `pady`.

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
label1 = tk.Label(racine, text="Un texte long dans ma fenêtre", font = ("helvetica", "30")) # création d'un widget
label2 = tk.Label(racine, text="toto",font = ("helvetica", "30")) # création d'un widget
label1.grid(column=0, row=0, padx=50) # positionnement du premier widget
label2.grid(column=0, row=1, pady=10) # positionnement du premier widget
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# Noter que, par défaut, le widget est centré verticalement et horizontalement à l'intérieur de sa case.
#
#  Par défaut, l'unité utilisée est le pixel. Pour changer l'unité, écrire, par exemple
# ```python
# padx="10cm"
# ```
#
# La marge peut être directement ajoutée à la création du widget par
# ```python
# label2 = tk.Label(racine, text="toto", padx=10)
# ```

# %% [markdown]
# **Exercice**
#
# ---
# Ecrire le programme qui affiche la fenêtre suivante qui comporte 8 labels. Ici les labels sont mis en relief pour mieux les distinguer mais on ne demande pas de le faire. Votre solution doit être la plus proche possible de ce qui s'affiche. La police utilisée est `("helvetica", "26")`.
#
#
# ![](exo.png)

# %%
def operande_g():
    global gauche
    gauche = int(input())
    label3.config(text= gauche)
def operande_d():
    global droite
    droite = int(input())
    label5.config(text= droite)
def calculer():
    a = gauche + droite
    label7.config(text= a)



import tkinter as tk
gauche = 0
droite = 0
racine = tk.Tk()
bouton = tk.Button(racine,text="choisir une valeur pour l'opérande gauche",font = ("helvtica","26"),command=operande_g)
bouton.grid(column=0, row= 1)


bouton1 = tk.Button(racine,text="choisire une valeur pour l'opérande droite",font = ("helvtica","26"), command= operande_d)
bouton1.grid(column=0, row= 2, padx= 25)

bouton2 = tk.Button(racine,text="calculer",command= calculer,font = ("helvtica","26"), )
bouton2.grid(column=2, row= 1, )

label3 = tk.Button(racine,text="",font = ("helvtica","26"))
label3.grid(column=1, row= 0,)

label4 = tk.Button(racine,text="+",font = ("helvtica","26"))
label4.grid(column=2, row= 0)

label5 = tk.Button(racine,text="",font = ("helvtica","26"))
label5.grid(column=3, row= 0)

label6 = tk.Button(racine,text="=",font = ("helvtica","26"))
label6.grid(column=4, row= 0)

label7 = tk.Label(racine,text="",font = ("helvtica","26"))
label7.grid(column=5, row= 0)

racine.mainloop()

# %% [markdown]
# ## 3. Widgets Label et Button
#
# ---
#
# Paramètres de choix de couleurs:
# * `fg` (ou `foreground`): couleur du texte
# * `bg` (ou `background`): couleur du fond
#
# Exemples de noms de couleurs:
# * white
# * black
# * red
# * green
# * blue
# * cyan
# * yellow
#
# On verra plus tard comment construire nos propres couleurs.

# %%
import tkinter as tk
import random as rd

couleurs = ["red", "green", "blue", "cyan", "yellow"]
couleur_fond = rd.choice(couleurs)
couleurs.remove(couleur_fond)
couleur_texte = rd.choice(couleurs)

racine = tk.Tk() # Création de la fenêtre racine

label = tk.Label(racine, bg=couleur_fond, fg=couleur_texte, text="couleur texte: " + couleur_texte + "\ncouleur fond: " + couleur_fond,padx=20, pady=20,font = ("helvetica", "30")   )
label.grid() # positionnement du premier widget

racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Modifier un paramètre d'un widget**
#
# ---
# Avec la méthode `.config()`
# ```python
# widget.config(param=new_value)
# ```

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
label = tk.Label(racine, text="Un texte long dans ma fenêtre", font = ("helvetica", "30")) # création d'un widget
label.config(text="autre texte", bg="blue") # modification des paramètres du widget
label.grid() 
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Exemple avec un widget Button**
#
# ---

# %%
import tkinter as tk

def affichage():
    """ Modifie le texte d'un label. """
    global cpt
    cpt += 1
    label.config(text="tu as cliqué " + str(cpt)+ " fois")

cpt = 0
racine = tk.Tk() # Création de la fenêtre racine
label = tk.Label(racine, text="texte avant de cliquer sur le bouton",
                  padx=20, pady=20, font = ("helvetica", "30") 
                )
label.grid(row=0, column=0)
bouton = tk.Button(racine, text="Un bouton sur lequel cliquer", 
                    command=affichage, font = ("helvetica", "30") 
                  ) # création du widget
bouton.grid(row=1, column=0) # positionnement du widget
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Rappel:** l'instruction `global cpt` permet de modifier la variable globale à l'intérieur de la fonction.

# %% [markdown]
# **Argument `command`**
#
# ---
#
# Cet argument permet d'appeler une fonction quand on clique sur le bouton.
# ```python
# bouton = tk.Button(racine, text="Un bouton sur lequel cliquer", command=affichage)
# ```
# La fonction est appelée *sans paramètres*. On appelle cela une fonction *callback*.
#
# Pour pouvoir utiliser des paramètres malgré tout, on peut utiliser une *fonction anonyme* de la manière suivante:
# ```python
# command=lambda : f(x, y, z)
# ```
# où `x, y` et `z` sont les arguments à passer à la fonction `f`.

# %%
import tkinter as tk

def affichage(texte):
    """ Modifie le texte d'un label. """
    label.config(text=texte)

racine = tk.Tk() # Création de la fenêtre racine
label = tk.Label(racine, text="", padx=20, pady=20, font = ("helvetica", "30"))
label.grid(row=0, column=0, columnspan=2)
bouton1 = tk.Button(racine, text="affichage 1", command=lambda : affichage("ils sont fous ces romains"),
                     font = ("helvetica", "30")
                   ) 
bouton1.grid(row=1, column=0) 
bouton2 = tk.Button(racine, text="affichage 2", 
                    command=lambda : affichage("quand lama faché, lui toujours faire ainsi"),
                    font = ("helvetica", "30") 
                   )
bouton2.grid(row=1, column=1) 
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Remarque:** l'argument `columnspan=2` permet de couvrir 2 colonnes de la grille dans l'appel à la méthode `label.grid()`.

# %% [markdown]
# **Exercice**
#
# ---
# Reprendre l'exercice précédent, à savoir le dessin de la fenêtre suivante:
#
# ![](exo.png)
#
# Maintenant les textes `choisir une valeur...` et `calculer` doivent être des boutons.
#
# * quand on clique sur `choisir une valeur...`, l'utilisateur doit entrer une valeur pour l'opérande de droite ou de gauche, et le nombre affiché doit être modifié en conséquence.
#
# * quand on clique sur `calculer`, le résultat de la somme doit s'afficher

# %%
def operande_g():
    global gauche
    gauche = int(input())
    label3.config(text= gauche)
def operande_d():
    global droite
    droite = int(input())
    label5.config(text= droite)
def calculer():
    a = gauche + droite
    label7.config(text= a)



import tkinter as tk
gauche = 0
droite = 0
racine = tk.Tk()
bouton = tk.Button(racine,text="choisir une valeur pour l'opérande gauche",font = ("helvtica","26"),command=operande_g)
bouton.grid(column=0, row= 1)


bouton1 = tk.Button(racine,text="choisire une valeur pour l'opérande droite",font = ("helvtica","26"), command= operande_d)
bouton1.grid(column=0, row= 2, padx= 25)

bouton2 = tk.Button(racine,text="calculer",command= calculer,font = ("helvtica","26"), )
bouton2.grid(column=2, row= 1, )

label3 = tk.Button(racine,text="",font = ("helvtica","26"))
label3.grid(column=1, row= 0,)

label4 = tk.Button(racine,text="+",font = ("helvtica","26"))
label4.grid(column=2, row= 0)

label5 = tk.Button(racine,text="",font = ("helvtica","26"))
label5.grid(column=3, row= 0)

label6 = tk.Button(racine,text="=",font = ("helvtica","26"))
label6.grid(column=4, row= 0)

label7 = tk.Label(racine,text="",font = ("helvtica","26"))
label7.grid(column=5, row= 0)

racine.mainloop()

# %% [markdown]
# ## 4. Widget Canvas
#
# ---
#
# Widget qui permet de dessiner des formes telles que des lignes, des cercles... et de les animer. Il est utile pour créer des jeux.

# %%
import tkinter as tk


racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=500, width=500)
canvas.grid()
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Dessiner des objets dans un canevas: la ligne brisée**
#
# ---

# %%
import tkinter as tk

HEIGHT = 500
WIDTH = 500

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="purple", height=HEIGHT, width=WIDTH)
canvas.grid()
canvas.create_line((0, 0), (WIDTH/4, HEIGHT/4),(WIDTH/2, 0), (3*WIDTH/4,HEIGHT/4),(WIDTH,0) ,fill="blue", width=5)
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Remarques:**
# * les parenthèses autour des coordonnées `(x, y)` sont facultatives, mais rendent le code plus lisible
# * l'axe des $x$ va de gauche à droite, et celui des $y$ va de haut en bas
# * les variables `WIDTH` et `HEIGHT` jouent le rôle de constantes, et sont écrites en majuscules

# %% [markdown]
# **Dessiner des objets dans un canevas: l'ellipse**
#
# ---

# %%
import tkinter as tk

HEIGHT = 500
WIDTH = 500

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=HEIGHT, width=WIDTH)
canvas.grid()
canvas.create_oval((100, 100),(400, 400), fill="blue", width=5, outline="cyan")
canvas.create_rectangle((100, 100), (400, 400))
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Remarque:** l'appel à
# ```python
# canvas.create_oval((x0, y0), (x1, y1))
# ```
# dessine l'ellipse inscrite dans le rectangle aux côtés horizontaux et verticaux ayant pour sommets opposés les points de coordonnées `(x0, y0)` et `(x1, y1)`. C'est un cercle si ce rectangle est un carré.

# %% [markdown]
# **Manipulation des objets dessinés**
#
# ---
#
# * en plus des lignes et des ellipses, le widget canvas permet de dessiner des polygones, des arcs de cercles.
# * les méthodes `.create_objet()` renvoient l'identifiant de l'objet qui a été créé. Des méthodes du canvas peuvent ensuite modifier l'objet grâce à son identifiant.

# %%
import tkinter as tk

HEIGHT = 500
WIDTH = 500

def bouge_cercle():
    canvas.move(cercle, 50, 50) # méthode qui déplace l'objet cercle

racine = tk.Tk() # Création de la fenêtre racine
bouton = tk.Button(text="déplace cercle", 
                    command=bouge_cercle, font = ("Helvetica", "30")
                  )
bouton.grid(column=0, row=1)
canvas = tk.Canvas(racine, bg="red", height=HEIGHT, width=WIDTH)
canvas.grid(column=0, row=0)
# on récupère l'identifiant du cercle:
cercle = canvas.create_oval((100, 100), (300, 300), fill="blue", width=5, outline="cyan") 
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Exercice: construire un damier de taille 8x8**
#
# ---
#
# Note: utiliser la méthode `.create_rectangle()`

# %%
def creer_damier():
    global a,b
    a = 100
    b += 100
   
    for i in range(0,8):
        for j in range (0,10):
            if (j+i)%2 == 0:
             rectangle = canvas.create_rectangle((j*100,i*100),((j+1)*100,(i+1)*100),fill= "blue")
            if (j+i)%2 != 0:
             rectangle = canvas.create_rectangle((j*100,i*100),((j+1)*100,(i+1)*100),fill= "white")



   





import tkinter as tk
a = 0
b = 0
racine = tk.Tk()
canvas = tk.Canvas(racine, bg="yellow", height= 1000, width= 1000)
canvas.grid(column=1,row=1)
bouton = tk.Button(racine, text="damier", command= creer_damier)
bouton.grid(column=0,row=0)
racine.mainloop()

# %%
import tkinter as tk

HEIGHT = 500
WIDTH = 500
largeur_case = WIDTH // 8
hauteur_case = HEIGHT // 8

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=HEIGHT, width=WIDTH)
canvas.grid()
for i in range(8):
    for j in range(8):
        if (i+j) % 2 == 0:
            color = "gray80"
        else:
            color = "black"
        canvas.create_rectangle((i*largeur_case, j*hauteur_case),
                ((i+1)*largeur_case, (j+1)*hauteur_case), fill=color)
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Couleurs**
#
# ---
#
# Comme on l'a vu, certaines couleurs sont déjà prédéfinies.
#
# ![](800px-TkInterColorCharts.png)
#
# Extrait de `http://stackoverflow.com/questions/4969543/colour-chart-for-tkinter-and-tix-using-python`

# %% [markdown]
# **Construire ses couleurs**
#
# ---
#
# Une couleur est codée par ses trois teintes `(rouge, vert, bleu)` qui peuvent prendre chacune une valeur entre 0 et 255.
#
# **Exemples:**
# * noir: (0, 0, 0)
# * blanc: (255, 255, 255)
# * gris: (x, x, x)
# * rouge: (255, 0, 0)
# * jaune: (255, 255, 0)
#
# Combien y a-t'il de couleurs différentes?
#
# Voici une fonction qui retourne une couleur sous le format attendu par tkinter à partir de ces 3 composantes (on ne demande pas de comprendre son fonctionnement):

# %%
def get_color(r=0, g=0, b=0):
    """ Retourne une couleur à partir de ses composantes r, g, b"""
    return '#{:02x}{:02x}{:02x}'.format(r, g, b)

# %% [markdown]
# **Utilisation de la fonction `get_color()`**
#
# ---
# Le programme demande 3 valeurs et affiche la couleur correspondante.

# %%
import tkinter as tk

def afficher_couleur():
    while True:
        r = int(input("Teinte de rouge? "))
        v = int(input("Teinte de vert? "))
        b = int(input("Teinte de bleu? "))
        if 0 <= r <= 255 and 0 <= v <= 255 and 0 <= b <= 255:
            break
    canvas.config(bg=get_color(r, v, b))
                      

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, width=400, height=400, bg="white")
canvas.grid(row=0)
bouton = tk.Button(racine, text="Choisir couleur", font=("Helvetica", "30"), command=afficher_couleur)
bouton.grid(row=1)

racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Remarque:** on aurait pu utiliser les champs de saisie pour récupérer les valeurs choisies par l'utilisateur dans la fenêtre graphique. Mais leur utilisation est plus complexe.

# %% [markdown]
# ## 5. Gestion des événements
#
# ---
#
# * Un *événement* est la survenue d'une action faite par l'utilisateur (clavier ou souris) à laquelle le programme doit réagir:
#
#     * clic sur un bouton de la souris
#     * déplacement de la souris
#     * appui sur une touche du clavier
#     * relâchement d'une touche du clavier
#     * un compte à rebours est écoulé (cet événement n'est pas déclenché directement par l'utilisateur)...
#
#
# * Par exemple, le widget Button réagit à un clic souris en appelant la fonction associé à son paramètre `command`.
#
#
# * De manière plus générale, on peut *lier* un événement à une action pour un événement qui surviendrait dans un widget donné de la manière suivante:
# ```python
# widget.bind(event, action)
# ```
# où
#     * `event` est un descripteur de l'événement à traiter
#     * `action` est la fonction (callback) à appeler quand l'événement survient

# %% [markdown]
# **Exemple: connaître les coordonnées du point cliqué**
#
# ---

# %%
import tkinter as tk

def affichage(event):
    print("clic aux coordonnées ", event.x , event.y)
    
racine = tk.Tk() # Création de la fenêtre racine
racine.bind("<Button-1>", affichage)
racine.mainloop() # Lancement de la boucle principale
# Out:
# clic aux coordonnées  140 47

# %% [markdown]
# **Méthode `.mainloop()`**
#
# ---
#
# La méthode `.mainloop()` implémente une boucle infinie dont on ne sort que en quittant le programme (clic sur la croix de fermeture de la fenêtre). A chaque itération:
#
# * elle exécute les actions liées aux événements associés aux widgets: méthode `.bind()`
# * elle exécute les actions dont le compte à rebours est arrivé à échéance: méthode `.after()`
#
# On appelle cela la *programmation événementielle*: le programme est défini par ses réactions aux événements qui peuvent se produire, dont l'ordre n'est pas pas connu à l'avance, au contraire de la *programmation séquentiel*.
#
# C'est aussi le paradigme de programmation utilisé en robotique.
#
# Toute fonction (comme `affichage`) appelée dans `bind` aura obligatoirement comme premier argument une variable de type événement (détails après). Cette variable se nomme `event` en général.

# %% [markdown]
# **Méthode `.mainloop()`**
#
# ---
# La méthode `.mainloop()` bloque l'exécution du programme et doit donc se placer à la fin.

# %%
import tkinter as tk


racine = tk.Tk() # Création de la fenêtre racine
racine.mainloop() # Lancement de la boucle principale
print("hello world")
# Out:
# hello world

# %% [markdown]
# **Format des événements**
#
# ---
# L'utilisation de la méthode `.bind()` nécessite de connaître le code associé aux événements. Par exemple, dans
# ```python
# canvas.bind("<Button-1>", affichage)
# ```
# `<Button-1>` désigne un clic gauche de la souris.
#
# Quelques événements standards:
# * `<Button-i>`: clic souris gauche si i vaut 1, central si i vaut 2 et droite si i vaut 3
# * `<ButtonRelease-i>`: relâchement d'un bouton de la souris (i vaut 1, 2 ou 3 comme ci-dessus)
# * `<KeyPress-i>`: touche `i` enfoncée
# * `<KeyRelease-i>`: touche `i` relachée
# * pleins d'autres exemples [ici](http://effbot.org/tkinterbook/tkinter-events-and-bindings.htm#events)

# %%
import tkinter as tk

def appui_a(event):
    print("Tu as appuyé sur la touche a")

def relache_a(event):
    print("Tu as relâché la touche a")
    
def affichage(event):
    print("toto")
    
racine = tk.Tk() # Création de la fenêtre racine
racine.bind("<KeyPress-a>", appui_a)
racine.bind("<KeyRelease-a>", relache_a)
racine.bind("<Button-1>", affichage)
racine.mainloop() # Lancement de la boucle principale
# Out:
# Tu as appuyé sur la touche a
# Tu as relâché la touche a
# Tu as appuyé sur la touche a
# Tu as relâché la touche a

# %% [markdown]
# **Remarques:**
# * maintenir la touche appuyé pendant un certain temps mène à répéter la suite d'appui - relâchement de la touche
# * pour recevoir un événement clavier, un widget doit avoir le *focus*, et, par défaut, le widget racine a bien le focus.

# %% [markdown]
# **Fonction callback**
#
# ---
#
# La fonction callback est la fonction appelée quand un événement se produit. La fonction doit accepter au moins un argument qui se nomme généralement `event` et est placé en premier argument de la fonction:
# ```python
# def fonction_callback(event, argument2...):
#     pass
# ```
# Cet argument permet de récupérer des informations sur l'événement. Quelques *attributs* utiles:
# * `event.x, event.y`: position de la souris par rapport à la fenêtre
# * `event.char`: le caractère (pour événement clavier) donné sous forme de string

# %%
import tkinter as tk

def appui_touche(event):
    print("Tu as appuyé sur la touche", event.char)

racine = tk.Tk() # Création de la fenêtre racine
racine.bind("<KeyPress>", appui_touche)
racine.mainloop() # Lancement de la boucle principale
# Out:
# Tu as appuyé sur la touche b
# Tu as appuyé sur la touche c
# Tu as appuyé sur la touche e
# Tu as appuyé sur la touche l
# Tu as appuyé sur la touche i
# Tu as appuyé sur la touche e
# Tu as appuyé sur la touche =
# Tu as appuyé sur la touche -
# Tu as appuyé sur la touche
# Tu as appuyé sur la touche "
# Tu as appuyé sur la touche
# Tu as appuyé sur la touche 3

# %% [markdown]
# **Remarque**: le programme fonctionne pour les touches correspondant à des caractères uniquement.

# %% [markdown]
# **Création de compte à rebours avec la méthode `.after()`**
#
# ---
#
# C'est une méthode commune à tous les widgets:
# ```python
# widget.after(delai, fonction)
# ```
# * `delai`: est la durée en ms avant d'appeler la fonction
# * `fonction`: est la fonction appelée

# %%
import tkinter as tk

cpt = 0
def affichage():
    global cpt
    cpt += 1
    print("Affichage numéro", cpt)
    racine.after(1000, affichage)

racine = tk.Tk() # Création de la fenêtre racine
affichage()
racine.mainloop() # Lancement de la boucle principale
# Out:
# Affichage numéro 1
# Affichage numéro 2
# Affichage numéro 3
# Affichage numéro 4
# Affichage numéro 5
# Affichage numéro 6
# Affichage numéro 7
# Affichage numéro 8
# Affichage numéro 9
# Affichage numéro 10
# Affichage numéro 11
# Affichage numéro 12
# Affichage numéro 13
# Affichage numéro 14
# Affichage numéro 15
# Affichage numéro 16
# Affichage numéro 17
# Affichage numéro 18
# Affichage numéro 19
# Affichage numéro 20
# Affichage numéro 21
# Affichage numéro 22
# Affichage numéro 23
# Affichage numéro 24
# Affichage numéro 25
# Affichage numéro 26
# Affichage numéro 27
# Affichage numéro 28
# Affichage numéro 29
# Affichage numéro 30
# Affichage numéro 31
# Affichage numéro 32
# Affichage numéro 33
# Affichage numéro 34
# Affichage numéro 35
# Affichage numéro 36
# Affichage numéro 37
# Affichage numéro 38
# Affichage numéro 39
# Affichage numéro 40
# Affichage numéro 41
# Affichage numéro 42
# Affichage numéro 43
# Affichage numéro 44
# Affichage numéro 45
# Affichage numéro 46
# Affichage numéro 47
# Affichage numéro 48
# Affichage numéro 49
# Affichage numéro 50
# Affichage numéro 51
# Affichage numéro 52
# Affichage numéro 53
# Affichage numéro 54
# Affichage numéro 55
# Affichage numéro 56
# Affichage numéro 57
# Affichage numéro 58
# Affichage numéro 59
# Affichage numéro 60
# Affichage numéro 61
# Affichage numéro 62
# Affichage numéro 63
# Affichage numéro 64
# Affichage numéro 65
# Affichage numéro 66
# Affichage numéro 67
# Affichage numéro 68
# Affichage numéro 69
# Affichage numéro 70
# Affichage numéro 71
# Affichage numéro 72
# Affichage numéro 73
# Affichage numéro 74
# Affichage numéro 75
# Affichage numéro 76
# Affichage numéro 77
# Affichage numéro 78
# Affichage numéro 79
# Affichage numéro 80
# Affichage numéro 81
# Affichage numéro 82
# Affichage numéro 83
# Affichage numéro 84
# Affichage numéro 85
# Affichage numéro 86
# Affichage numéro 87
# Affichage numéro 88
# Affichage numéro 89
# Affichage numéro 90
# Affichage numéro 91
# Affichage numéro 92
# Affichage numéro 93
# Affichage numéro 94
# Affichage numéro 95
# Affichage numéro 96
# Affichage numéro 97
# Affichage numéro 98
# Affichage numéro 99
# Affichage numéro 100
# Affichage numéro 101
# Affichage numéro 102
# Affichage numéro 103
# Affichage numéro 104
# Affichage numéro 105
# Affichage numéro 106
# Affichage numéro 107
# Affichage numéro 108
# Affichage numéro 109
# Affichage numéro 110
# Affichage numéro 111
# Affichage numéro 112
# Affichage numéro 113
# Affichage numéro 114
# Affichage numéro 115
# Affichage numéro 116
# Affichage numéro 117
# Affichage numéro 118
# Affichage numéro 119
# Affichage numéro 120
# Affichage numéro 121
# Affichage numéro 122
# Affichage numéro 123
# Affichage numéro 124
# Affichage numéro 125
# Affichage numéro 126
# Affichage numéro 127
# Affichage numéro 128
# Affichage numéro 129
# Affichage numéro 130
# Affichage numéro 131
# Affichage numéro 132
# Affichage numéro 133
# Affichage numéro 134
# Affichage numéro 135
# Affichage numéro 136
# Affichage numéro 137
# Affichage numéro 138
# Affichage numéro 139
# Affichage numéro 140
# Affichage numéro 141
# Affichage numéro 142
# Affichage numéro 143
# Affichage numéro 144
# Affichage numéro 145
# Affichage numéro 146
# Affichage numéro 147
# Affichage numéro 148
# Affichage numéro 149
# Affichage numéro 150
# Affichage numéro 151
# Affichage numéro 152
# Affichage numéro 153
# Affichage numéro 154
# Affichage numéro 155
# Affichage numéro 156
# Affichage numéro 157
# Affichage numéro 158
# Affichage numéro 159
# Affichage numéro 160
# Affichage numéro 161
# Affichage numéro 162
# Affichage numéro 163
# Affichage numéro 164
# Affichage numéro 165
# Affichage numéro 166
# Affichage numéro 167
# Affichage numéro 168
# Affichage numéro 169
# Affichage numéro 170
# Affichage numéro 171
# Affichage numéro 172
# Affichage numéro 173
# Affichage numéro 174
# Affichage numéro 175
# Affichage numéro 176
# Affichage numéro 177
# Affichage numéro 178
# Affichage numéro 179
# Affichage numéro 180
# Affichage numéro 181
# Affichage numéro 182
# Affichage numéro 183
# Affichage numéro 184
# Affichage numéro 185
# Affichage numéro 186
# Affichage numéro 187
# Affichage numéro 188
# Affichage numéro 189
# Affichage numéro 190
# Affichage numéro 191
# Affichage numéro 192
# Affichage numéro 193
# Affichage numéro 194
# Affichage numéro 195
# Affichage numéro 196
# Affichage numéro 197
# Affichage numéro 198
# Affichage numéro 199
# Affichage numéro 200
# Affichage numéro 201
# Affichage numéro 202
# Affichage numéro 203
# Affichage numéro 204
# Affichage numéro 205
# Affichage numéro 206
# Affichage numéro 207
# Affichage numéro 208
# Affichage numéro 209
# Affichage numéro 210
# Affichage numéro 211
# Affichage numéro 212
# Affichage numéro 213
# Affichage numéro 214
# Affichage numéro 215
# Affichage numéro 216
# Affichage numéro 217
# Affichage numéro 218
# Affichage numéro 219
# Affichage numéro 220
# Affichage numéro 221
# Affichage numéro 222
# Affichage numéro 223
# Affichage numéro 224
# Affichage numéro 225
# Affichage numéro 226
# Affichage numéro 227
# Affichage numéro 228
# Affichage numéro 229
# Affichage numéro 230
# Affichage numéro 231
# Affichage numéro 232
# Affichage numéro 233
# Affichage numéro 234
# Affichage numéro 235
# Affichage numéro 236
# Affichage numéro 237
# Affichage numéro 238
# Affichage numéro 239
# Affichage numéro 240
# Affichage numéro 241
# Affichage numéro 242
# Affichage numéro 243
# Affichage numéro 244
# Affichage numéro 245
# Affichage numéro 246
# Affichage numéro 247
# Affichage numéro 248
# Affichage numéro 249
# Affichage numéro 250
# Affichage numéro 251
# Affichage numéro 252
# Affichage numéro 253
# Affichage numéro 254
# Affichage numéro 255
# Affichage numéro 256
# Affichage numéro 257
# Affichage numéro 258
# Affichage numéro 259
# Affichage numéro 260
# Affichage numéro 261
# Affichage numéro 262
# Affichage numéro 263
# Affichage numéro 264
# Affichage numéro 265
# Affichage numéro 266
# Affichage numéro 267
# Affichage numéro 268
# Affichage numéro 269
# Affichage numéro 270
# Affichage numéro 271
# Affichage numéro 272
# Affichage numéro 273
# Affichage numéro 274
# Affichage numéro 275
# Affichage numéro 276
# Affichage numéro 277
# Affichage numéro 278
# Affichage numéro 279
# Affichage numéro 280
# Affichage numéro 281
# Affichage numéro 282
# Affichage numéro 283
# Affichage numéro 284
# Affichage numéro 285
# Affichage numéro 286
# Affichage numéro 287
# Affichage numéro 288
# Affichage numéro 289
# Affichage numéro 290
# Affichage numéro 291
# Affichage numéro 292
# Affichage numéro 293
# Affichage numéro 294
# Affichage numéro 295
# Affichage numéro 296
# Affichage numéro 297
# Affichage numéro 298
# Affichage numéro 299
# Affichage numéro 300
# Affichage numéro 301
# Affichage numéro 302
# Affichage numéro 303
# Affichage numéro 304
# Affichage numéro 305
# Affichage numéro 306
# Affichage numéro 307
# Affichage numéro 308
# Affichage numéro 309
# Affichage numéro 310
# Affichage numéro 311
# Affichage numéro 312
# Affichage numéro 313
# Affichage numéro 314
# Affichage numéro 315
# Affichage numéro 316
# Affichage numéro 317
# Affichage numéro 318
# Affichage numéro 319
# Affichage numéro 320
# Affichage numéro 321
# Affichage numéro 322
# Affichage numéro 323
# Affichage numéro 324
# Affichage numéro 325
# Affichage numéro 326
# Affichage numéro 327
# Affichage numéro 328
# Affichage numéro 329
# Affichage numéro 330
# Affichage numéro 331
# Affichage numéro 332
# Affichage numéro 333
# Affichage numéro 334
# Affichage numéro 335
# Affichage numéro 336
# Affichage numéro 337
# Affichage numéro 338
# Affichage numéro 339
# Affichage numéro 340
# Affichage numéro 341
# Affichage numéro 342
# Affichage numéro 343
# Affichage numéro 344
# Affichage numéro 345
# Affichage numéro 346
# Affichage numéro 347
# Affichage numéro 348
# Affichage numéro 349
# Affichage numéro 350
# Affichage numéro 351
# Affichage numéro 352
# Affichage numéro 353
# Affichage numéro 354
# Affichage numéro 355
# Affichage numéro 356
# Affichage numéro 357
# Affichage numéro 358
# Affichage numéro 359
# Affichage numéro 360
# Affichage numéro 361
# Affichage numéro 362
# Affichage numéro 363
# Affichage numéro 364
# Affichage numéro 365
# Affichage numéro 366
# Affichage numéro 367
# Affichage numéro 368
# Affichage numéro 369
# Affichage numéro 370
# Affichage numéro 371
# Affichage numéro 372
# Affichage numéro 373
# Affichage numéro 374
# Affichage numéro 375
# Affichage numéro 376
# Affichage numéro 377
# Affichage numéro 378
# Affichage numéro 379
# Affichage numéro 380
# Affichage numéro 381
# Affichage numéro 382
# Affichage numéro 383
# Affichage numéro 384
# Affichage numéro 385
# Affichage numéro 386
# Affichage numéro 387
# Affichage numéro 388
# Affichage numéro 389
# Affichage numéro 390
# Affichage numéro 391
# Affichage numéro 392
# Affichage numéro 393
# Affichage numéro 394
# Affichage numéro 395
# Affichage numéro 396
# Affichage numéro 397
# Affichage numéro 398
# Affichage numéro 399
# Affichage numéro 400
# Affichage numéro 401
# Affichage numéro 402
# Affichage numéro 403
# Affichage numéro 404
# Affichage numéro 405
# Affichage numéro 406
# Affichage numéro 407
# Affichage numéro 408
# Affichage numéro 409
# Affichage numéro 410
# Affichage numéro 411
# Affichage numéro 412
# Affichage numéro 413
# Affichage numéro 414
# Affichage numéro 415
# Affichage numéro 416
# Affichage numéro 417
# Affichage numéro 418
# Affichage numéro 419
# Affichage numéro 420
# Affichage numéro 421
# Affichage numéro 422
# Affichage numéro 423
# Affichage numéro 424
# Affichage numéro 425
# Affichage numéro 426
# Affichage numéro 427
# Affichage numéro 428
# Affichage numéro 429
# Affichage numéro 430
# Affichage numéro 431
# Affichage numéro 432
# Affichage numéro 433
# Affichage numéro 434
# Affichage numéro 435
# Affichage numéro 436
# Affichage numéro 437
# Affichage numéro 438
# Affichage numéro 439
# Affichage numéro 440
# Affichage numéro 441
# Affichage numéro 442
# Affichage numéro 443
# Affichage numéro 444
# Affichage numéro 445
# Affichage numéro 446
# Affichage numéro 447
# Affichage numéro 448
# Affichage numéro 449
# Affichage numéro 450
# Affichage numéro 451
# Affichage numéro 452
# Affichage numéro 453
# Affichage numéro 454
# Affichage numéro 455
# Affichage numéro 456
# Affichage numéro 457
# Affichage numéro 458
# Affichage numéro 459
# Affichage numéro 460
# Affichage numéro 461
# Affichage numéro 462
# Affichage numéro 463
# Affichage numéro 464
# Affichage numéro 465
# Affichage numéro 466
# Affichage numéro 467
# Affichage numéro 468
# Affichage numéro 469
# Affichage numéro 470
# Affichage numéro 471
# Affichage numéro 472
# Affichage numéro 473
# Affichage numéro 474
# Affichage numéro 475
# Affichage numéro 476
# Affichage numéro 477
# Affichage numéro 478
# Affichage numéro 479
# Affichage numéro 480
# Affichage numéro 481
# Affichage numéro 482
# Affichage numéro 483
# Affichage numéro 484
# Affichage numéro 485
# Affichage numéro 486
# Affichage numéro 487
# Affichage numéro 488
# Affichage numéro 489
# Affichage numéro 490
# Affichage numéro 491
# Affichage numéro 492
# Affichage numéro 493
# Affichage numéro 494
# Affichage numéro 495
# Affichage numéro 496
# Affichage numéro 497
# Affichage numéro 498
# Affichage numéro 499
# Affichage numéro 500
# Affichage numéro 501
# Affichage numéro 502
# Affichage numéro 503
# Affichage numéro 504
# Affichage numéro 505
# Affichage numéro 506
# Affichage numéro 507
# Affichage numéro 508
# Affichage numéro 509
# Affichage numéro 510
# Affichage numéro 511
# Affichage numéro 512
# Affichage numéro 513
# Affichage numéro 514
# Affichage numéro 515
# Affichage numéro 516
# Affichage numéro 517
# Affichage numéro 518
# Affichage numéro 519
# Affichage numéro 520
# Affichage numéro 521
# Affichage numéro 522
# Affichage numéro 523
# Affichage numéro 524
# Affichage numéro 525
# Affichage numéro 526
# Affichage numéro 527
# Affichage numéro 528
# Affichage numéro 529
# Affichage numéro 530
# Affichage numéro 531
# Affichage numéro 532
# Affichage numéro 533
# Affichage numéro 534
# Affichage numéro 535
# Affichage numéro 536
# Affichage numéro 537
# Affichage numéro 538
# Affichage numéro 539
# Affichage numéro 540
# Affichage numéro 541
# Affichage numéro 542
# Affichage numéro 543
# Affichage numéro 544
# Affichage numéro 545
# Affichage numéro 546
# Affichage numéro 547
# Affichage numéro 548
# Affichage numéro 549
# Affichage numéro 550
# Affichage numéro 551
# Affichage numéro 552
# Affichage numéro 553
# Affichage numéro 554
# Affichage numéro 555
# Affichage numéro 556
# Affichage numéro 557
# Affichage numéro 558
# Affichage numéro 559
# Affichage numéro 560
# Affichage numéro 561
# Affichage numéro 562
# Affichage numéro 563
# Affichage numéro 564
# Affichage numéro 565
# Affichage numéro 566
# Affichage numéro 567
# Affichage numéro 568
# Affichage numéro 569
# Affichage numéro 570
# Affichage numéro 571
# Affichage numéro 572
# Affichage numéro 573
# Affichage numéro 574
# Affichage numéro 575
# Affichage numéro 576
# Affichage numéro 577
# Affichage numéro 578
# Affichage numéro 579
# Affichage numéro 580
# Affichage numéro 581
# Affichage numéro 582
# Affichage numéro 583
# Affichage numéro 584
# Affichage numéro 585
# Affichage numéro 586
# Affichage numéro 587
# Affichage numéro 588
# Affichage numéro 589
# Affichage numéro 590
# Affichage numéro 591
# Affichage numéro 592
# Affichage numéro 593
# Affichage numéro 594
# Affichage numéro 595
# Affichage numéro 596
# Affichage numéro 597
# Affichage numéro 598
# Affichage numéro 599
# Affichage numéro 600
# Affichage numéro 601
# Affichage numéro 602
# Affichage numéro 603
# Affichage numéro 604
# Affichage numéro 605
# Affichage numéro 606
# Affichage numéro 607
# Affichage numéro 608
# Affichage numéro 609
# Affichage numéro 610
# Affichage numéro 611
# Affichage numéro 612
# Affichage numéro 613
# Affichage numéro 614
# Affichage numéro 615
# Affichage numéro 616
# Affichage numéro 617
# Affichage numéro 618
# Affichage numéro 619
# Affichage numéro 620
# Affichage numéro 621
# Affichage numéro 622
# Affichage numéro 623
# Affichage numéro 624
# Affichage numéro 625
# Affichage numéro 626
# Affichage numéro 627
# Affichage numéro 628
# Affichage numéro 629
# Affichage numéro 630
# Affichage numéro 631
# Affichage numéro 632
# Affichage numéro 633
# Affichage numéro 634
# Affichage numéro 635
# Affichage numéro 636
# Affichage numéro 637
# Affichage numéro 638
# Affichage numéro 639
# Affichage numéro 640
# Affichage numéro 641
# Affichage numéro 642
# Affichage numéro 643
# Affichage numéro 644
# Affichage numéro 645
# Affichage numéro 646
# Affichage numéro 647
# Affichage numéro 648
# Affichage numéro 649
# Affichage numéro 650
# Affichage numéro 651
# Affichage numéro 652
# Affichage numéro 653
# Affichage numéro 654
# Affichage numéro 655
# Affichage numéro 656
# Affichage numéro 657
# Affichage numéro 658
# Affichage numéro 659
# Affichage numéro 660
# Affichage numéro 661
# Affichage numéro 662
# Affichage numéro 663
# Affichage numéro 664
# Affichage numéro 665
# Affichage numéro 666
# Affichage numéro 667
# Affichage numéro 668
# Affichage numéro 669
# Affichage numéro 670
# Affichage numéro 671
# Affichage numéro 672
# Affichage numéro 673
# Affichage numéro 674
# Affichage numéro 675
# Affichage numéro 676
# Affichage numéro 677
# Affichage numéro 678
# Affichage numéro 679
# Affichage numéro 680
# Affichage numéro 681
# Affichage numéro 682
# Affichage numéro 683
# Affichage numéro 684
# Affichage numéro 685
# Affichage numéro 686
# Affichage numéro 687
# Affichage numéro 688
# Affichage numéro 689
# Affichage numéro 690
# Affichage numéro 691
# Affichage numéro 692
# Affichage numéro 693
# Affichage numéro 694
# Affichage numéro 695
# Affichage numéro 696
# Affichage numéro 697
# Affichage numéro 698
# Affichage numéro 699
# Affichage numéro 700
# Affichage numéro 701
# Affichage numéro 702
# Affichage numéro 703
# Affichage numéro 704
# Affichage numéro 705
# Affichage numéro 706
# Affichage numéro 707
# Affichage numéro 708
# Affichage numéro 709
# Affichage numéro 710
# Affichage numéro 711
# Affichage numéro 712
# Affichage numéro 713
# Affichage numéro 714
# Affichage numéro 715
# Affichage numéro 716
# Affichage numéro 717
# Affichage numéro 718
# Affichage numéro 719
# Affichage numéro 720
# Affichage numéro 721
# Affichage numéro 722
# Affichage numéro 723
# Affichage numéro 724
# Affichage numéro 725
# Affichage numéro 726
# Affichage numéro 727
# Affichage numéro 728
# Affichage numéro 729
# Affichage numéro 730
# Affichage numéro 731
# Affichage numéro 732
# Affichage numéro 733
# Affichage numéro 734
# Affichage numéro 735
# Affichage numéro 736
# Affichage numéro 737
# Affichage numéro 738
# Affichage numéro 739
# Affichage numéro 740
# Affichage numéro 741
# Affichage numéro 742
# Affichage numéro 743
# Affichage numéro 744
# Affichage numéro 745
# Affichage numéro 746
# Affichage numéro 747
# Affichage numéro 748
# Affichage numéro 749
# Affichage numéro 750
# Affichage numéro 751
# Affichage numéro 752
# Affichage numéro 753
# Affichage numéro 754
# Affichage numéro 755
# Affichage numéro 756
# Affichage numéro 757
# Affichage numéro 758
# Affichage numéro 759
# Affichage numéro 760
# Affichage numéro 761
# Affichage numéro 762
# Affichage numéro 763
# Affichage numéro 764
# Affichage numéro 765
# Affichage numéro 766
# Affichage numéro 767
# Affichage numéro 768
# Affichage numéro 769
# Affichage numéro 770
# Affichage numéro 771
# Affichage numéro 772
# Affichage numéro 773
# Affichage numéro 774
# Affichage numéro 775
# Affichage numéro 776
# Affichage numéro 777
# Affichage numéro 778
# Affichage numéro 779
# Affichage numéro 780
# Affichage numéro 781
# Affichage numéro 782
# Affichage numéro 783
# Affichage numéro 784
# Affichage numéro 785
# Affichage numéro 786
# Affichage numéro 787
# Affichage numéro 788
# Affichage numéro 789
# Affichage numéro 790
# Affichage numéro 791
# Affichage numéro 792
# Affichage numéro 793
# Affichage numéro 794
# Affichage numéro 795
# Affichage numéro 796
# Affichage numéro 797
# Affichage numéro 798
# Affichage numéro 799
# Affichage numéro 800
# Affichage numéro 801
# Affichage numéro 802
# Affichage numéro 803
# Affichage numéro 804
# Affichage numéro 805
# Affichage numéro 806
# Affichage numéro 807
# Affichage numéro 808
# Affichage numéro 809
# Affichage numéro 810
# Affichage numéro 811
# Affichage numéro 812
# Affichage numéro 813
# Affichage numéro 814
# Affichage numéro 815
# Affichage numéro 816
# Affichage numéro 817
# Affichage numéro 818
# Affichage numéro 819
# Affichage numéro 820
# Affichage numéro 821
# Affichage numéro 822
# Affichage numéro 823
# Affichage numéro 824
# Affichage numéro 825
# Affichage numéro 826
# Affichage numéro 827
# Affichage numéro 828
# Affichage numéro 829
# Affichage numéro 830
# Affichage numéro 831
# Affichage numéro 832
# Affichage numéro 833
# Affichage numéro 834
# Affichage numéro 835
# Affichage numéro 836
# Affichage numéro 837
# Affichage numéro 838
# Affichage numéro 839
# Affichage numéro 840
# Affichage numéro 841
# Affichage numéro 842
# Affichage numéro 843
# Affichage numéro 844
# Affichage numéro 845
# Affichage numéro 846
# Affichage numéro 847
# Affichage numéro 848
# Affichage numéro 849
# Affichage numéro 850
# Affichage numéro 851
# Affichage numéro 852
# Affichage numéro 853
# Affichage numéro 854
# Affichage numéro 855
# Affichage numéro 856
# Affichage numéro 857
# Affichage numéro 858
# Affichage numéro 859
# Affichage numéro 860
# Affichage numéro 861
# Affichage numéro 862
# Affichage numéro 863
# Affichage numéro 864
# Affichage numéro 865
# Affichage numéro 866
# Affichage numéro 867
# Affichage numéro 868
# Affichage numéro 869
# Affichage numéro 870
# Affichage numéro 871
# Affichage numéro 872
# Affichage numéro 873
# Affichage numéro 874
# Affichage numéro 875
# Affichage numéro 876
# Affichage numéro 877
# Affichage numéro 878
# Affichage numéro 879
# Affichage numéro 880
# Affichage numéro 881
# Affichage numéro 882
# Affichage numéro 883
# Affichage numéro 884
# Affichage numéro 885
# Affichage numéro 886
# Affichage numéro 887
# Affichage numéro 888
# Affichage numéro 889
# Affichage numéro 890
# Affichage numéro 891
# Affichage numéro 892
# Affichage numéro 893
# Affichage numéro 894
# Affichage numéro 895
# Affichage numéro 896
# Affichage numéro 897
# Affichage numéro 898
# Affichage numéro 899
# Affichage numéro 900
# Affichage numéro 901
# Affichage numéro 902
# Affichage numéro 903
# Affichage numéro 904
# Affichage numéro 905
# Affichage numéro 906
# Affichage numéro 907
# Affichage numéro 908
# Affichage numéro 909
# Affichage numéro 910
# Affichage numéro 911
# Affichage numéro 912
# Affichage numéro 913
# Affichage numéro 914
# Affichage numéro 915
# Affichage numéro 916
# Affichage numéro 917
# Affichage numéro 918
# Affichage numéro 919
# Affichage numéro 920
# Affichage numéro 921
# Affichage numéro 922
# Affichage numéro 923
# Affichage numéro 924
# Affichage numéro 925
# Affichage numéro 926
# Affichage numéro 927
# Affichage numéro 928
# Affichage numéro 929
# Affichage numéro 930
# Affichage numéro 931
# Affichage numéro 932
# Affichage numéro 933
# Affichage numéro 934
# Affichage numéro 935
# Affichage numéro 936
# Affichage numéro 937
# Affichage numéro 938
# Affichage numéro 939
# Affichage numéro 940
# Affichage numéro 941
# Affichage numéro 942
# Affichage numéro 943
# Affichage numéro 944
# Affichage numéro 945
# Affichage numéro 946
# Affichage numéro 947
# Affichage numéro 948
# Affichage numéro 949
# Affichage numéro 950
# Affichage numéro 951
# Affichage numéro 952
# Affichage numéro 953
# Affichage numéro 954
# Affichage numéro 955
# Affichage numéro 956
# Affichage numéro 957
# Affichage numéro 958
# Affichage numéro 959
# Affichage numéro 960
# Affichage numéro 961
# Affichage numéro 962
# Affichage numéro 963
# Affichage numéro 964
# Affichage numéro 965
# Affichage numéro 966
# Affichage numéro 967
# Affichage numéro 968
# Affichage numéro 969
# Affichage numéro 970
# Affichage numéro 971
# Affichage numéro 972
# Affichage numéro 973
# Affichage numéro 974
# Affichage numéro 975
# Affichage numéro 976
# Affichage numéro 977
# Affichage numéro 978
# Affichage numéro 979
# Affichage numéro 980
# Affichage numéro 981
# Affichage numéro 982
# Affichage numéro 983
# Affichage numéro 984
# Affichage numéro 985
# Affichage numéro 986
# Affichage numéro 987
# Affichage numéro 988
# Affichage numéro 989
# Affichage numéro 990
# Affichage numéro 991
# Affichage numéro 992
# Affichage numéro 993
# Affichage numéro 994
# Affichage numéro 995
# Affichage numéro 996
# Affichage numéro 997
# Affichage numéro 998
# Affichage numéro 999
# Affichage numéro 1000
# Affichage numéro 1001
# Affichage numéro 1002
# Affichage numéro 1003
# Affichage numéro 1004
# Affichage numéro 1005
# Affichage numéro 1006
# Affichage numéro 1007
# Affichage numéro 1008
# Affichage numéro 1009
# Affichage numéro 1010
# Affichage numéro 1011
# Affichage numéro 1012
# Affichage numéro 1013
# Affichage numéro 1014
# Affichage numéro 1015
# Affichage numéro 1016
# Affichage numéro 1017
# Affichage numéro 1018
# Affichage numéro 1019
# Affichage numéro 1020
# Affichage numéro 1021
# Affichage numéro 1022
# Affichage numéro 1023
# Affichage numéro 1024
# Affichage numéro 1025
# Affichage numéro 1026
# Affichage numéro 1027
# Affichage numéro 1028
# Affichage numéro 1029
# Affichage numéro 1030
# Affichage numéro 1031
# Affichage numéro 1032
# Affichage numéro 1033
# Affichage numéro 1034
# Affichage numéro 1035
# Affichage numéro 1036
# Affichage numéro 1037
# Affichage numéro 1038
# Affichage numéro 1039
# Affichage numéro 1040
# Affichage numéro 1041
# Affichage numéro 1042
# Affichage numéro 1043
# Affichage numéro 1044
# Affichage numéro 1045
# Affichage numéro 1046
# Affichage numéro 1047
# Affichage numéro 1048
# Affichage numéro 1049
# Affichage numéro 1050
# Affichage numéro 1051
# Affichage numéro 1052
# Affichage numéro 1053
# Affichage numéro 1054
# Affichage numéro 1055
# Affichage numéro 1056
# Affichage numéro 1057
# Affichage numéro 1058
# Affichage numéro 1059
# Affichage numéro 1060
# Affichage numéro 1061
# Affichage numéro 1062
# Affichage numéro 1063
# Affichage numéro 1064
# Affichage numéro 1065
# Affichage numéro 1066
# Affichage numéro 1067
# Affichage numéro 1068
# Affichage numéro 1069
# Affichage numéro 1070
# Affichage numéro 1071
# Affichage numéro 1072
# Affichage numéro 1073
# Affichage numéro 1074
# Affichage numéro 1075
# Affichage numéro 1076
# Affichage numéro 1077
# Affichage numéro 1078
# Affichage numéro 1079
# Affichage numéro 1080
# Affichage numéro 1081
# Affichage numéro 1082
# Affichage numéro 1083
# Affichage numéro 1084
# Affichage numéro 1085
# Affichage numéro 1086
# Affichage numéro 1087
# Affichage numéro 1088
# Affichage numéro 1089
# Affichage numéro 1090
# Affichage numéro 1091
# Affichage numéro 1092
# Affichage numéro 1093
# Affichage numéro 1094
# Affichage numéro 1095
# Affichage numéro 1096
# Affichage numéro 1097
# Affichage numéro 1098
# Affichage numéro 1099
# Affichage numéro 1100
# Affichage numéro 1101
# Affichage numéro 1102
# Affichage numéro 1103
# Affichage numéro 1104
# Affichage numéro 1105
# Affichage numéro 1106
# Affichage numéro 1107
# Affichage numéro 1108
# Affichage numéro 1109
# Affichage numéro 1110
# Affichage numéro 1111
# Affichage numéro 1112
# Affichage numéro 1113
# Affichage numéro 1114
# Affichage numéro 1115
# Affichage numéro 1116
# Affichage numéro 1117
# Affichage numéro 1118
# Affichage numéro 1119
# Affichage numéro 1120
# Affichage numéro 1121
# Affichage numéro 1122
# Affichage numéro 1123
# Affichage numéro 1124
# Affichage numéro 1125
# Affichage numéro 1126
# Affichage numéro 1127
# Affichage numéro 1128
# Affichage numéro 1129
# Affichage numéro 1130
# Affichage numéro 1131
# Affichage numéro 1132
# Affichage numéro 1133
# Affichage numéro 1134
# Affichage numéro 1135
# Affichage numéro 1136
# Affichage numéro 1137
# Affichage numéro 1138
# Affichage numéro 1139
# Affichage numéro 1140
# Affichage numéro 1141
# Affichage numéro 1142
# Affichage numéro 1143
# Affichage numéro 1144
# Affichage numéro 1145
# Affichage numéro 1146
# Affichage numéro 1147
# Affichage numéro 1148
# Affichage numéro 1149
# Affichage numéro 1150
# Affichage numéro 1151
# Affichage numéro 1152
# Affichage numéro 1153
# Affichage numéro 1154
# Affichage numéro 1155
# Affichage numéro 1156
# Affichage numéro 1157
# Affichage numéro 1158
# Affichage numéro 1159
# Affichage numéro 1160
# Affichage numéro 1161
# Affichage numéro 1162
# Affichage numéro 1163
# Affichage numéro 1164
# Affichage numéro 1165
# Affichage numéro 1166
# Affichage numéro 1167
# Affichage numéro 1168
# Affichage numéro 1169
# Affichage numéro 1170
# Affichage numéro 1171
# Affichage numéro 1172
# Affichage numéro 1173
# Affichage numéro 1174
# Affichage numéro 1175
# Affichage numéro 1176
# Affichage numéro 1177
# Affichage numéro 1178
# Affichage numéro 1179
# Affichage numéro 1180
# Affichage numéro 1181
# Affichage numéro 1182
# Affichage numéro 1183
# Affichage numéro 1184
# Affichage numéro 1185
# Affichage numéro 1186
# Affichage numéro 1187
# Affichage numéro 1188
# Affichage numéro 1189
# Affichage numéro 1190
# Affichage numéro 1191
# Affichage numéro 1192
# Affichage numéro 1193
# Affichage numéro 1194
# Affichage numéro 1195
# Affichage numéro 1196
# Affichage numéro 1197
# Affichage numéro 1198
# Affichage numéro 1199
# Affichage numéro 1200
# Affichage numéro 1201
# Affichage numéro 1202
# Affichage numéro 1203
# Affichage numéro 1204
# Affichage numéro 1205
# Affichage numéro 1206
# Affichage numéro 1207
# Affichage numéro 1208
# Affichage numéro 1209
# Affichage numéro 1210
# Affichage numéro 1211
# Affichage numéro 1212
# Affichage numéro 1213
# Affichage numéro 1214
# Affichage numéro 1215
# Affichage numéro 1216
# Affichage numéro 1217
# Affichage numéro 1218
# Affichage numéro 1219
# Affichage numéro 1220
# Affichage numéro 1221
# Affichage numéro 1222
# Affichage numéro 1223
# Affichage numéro 1224
# Affichage numéro 1225
# Affichage numéro 1226
# Affichage numéro 1227
# Affichage numéro 1228
# Affichage numéro 1229
# Affichage numéro 1230
# Affichage numéro 1231
# Affichage numéro 1232
# Affichage numéro 1233
# Affichage numéro 1234
# Affichage numéro 1235
# Affichage numéro 1236
# Affichage numéro 1237
# Affichage numéro 1238
# Affichage numéro 1239
# Affichage numéro 1240
# Affichage numéro 1241
# Affichage numéro 1242
# Affichage numéro 1243
# Affichage numéro 1244
# Affichage numéro 1245
# Affichage numéro 1246
# Affichage numéro 1247
# Affichage numéro 1248
# Affichage numéro 1249
# Affichage numéro 1250
# Affichage numéro 1251
# Affichage numéro 1252
# Affichage numéro 1253
# Affichage numéro 1254
# Affichage numéro 1255
# Affichage numéro 1256
# Affichage numéro 1257
# Affichage numéro 1258
# Affichage numéro 1259
# Affichage numéro 1260
# Affichage numéro 1261
# Affichage numéro 1262
# Affichage numéro 1263
# Affichage numéro 1264
# Affichage numéro 1265
# Affichage numéro 1266
# Affichage numéro 1267
# Affichage numéro 1268
# Affichage numéro 1269
# Affichage numéro 1270
# Affichage numéro 1271
# Affichage numéro 1272
# Affichage numéro 1273
# Affichage numéro 1274
# Affichage numéro 1275
# Affichage numéro 1276
# Affichage numéro 1277
# Affichage numéro 1278
# Affichage numéro 1279
# Affichage numéro 1280
# Affichage numéro 1281
# Affichage numéro 1282
# Affichage numéro 1283
# Affichage numéro 1284
# Affichage numéro 1285
# Affichage numéro 1286
# Affichage numéro 1287
# Affichage numéro 1288
# Affichage numéro 1289
# Affichage numéro 1290
# Affichage numéro 1291
# Affichage numéro 1292
# Affichage numéro 1293
# Affichage numéro 1294
# Affichage numéro 1295
# Affichage numéro 1296
# Affichage numéro 1297
# Affichage numéro 1298
# Affichage numéro 1299
# Affichage numéro 1300
# Affichage numéro 1301
# Affichage numéro 1302
# Affichage numéro 1303
# Affichage numéro 1304
# Affichage numéro 1305
# Affichage numéro 1306
# Affichage numéro 1307
# Affichage numéro 1308
# Affichage numéro 1309
# Affichage numéro 1310
# Affichage numéro 1311
# Affichage numéro 1312
# Affichage numéro 1313
# Affichage numéro 1314
# Affichage numéro 1315
# Affichage numéro 1316
# Affichage numéro 1317
# Affichage numéro 1318
# Affichage numéro 1319
# Affichage numéro 1320
# Affichage numéro 1321
# Affichage numéro 1322
# Affichage numéro 1323
# Affichage numéro 1324
# Affichage numéro 1325
# Affichage numéro 1326
# Affichage numéro 1327
# Affichage numéro 1328
# Affichage numéro 1329
# Affichage numéro 1330
# Affichage numéro 1331
# Affichage numéro 1332
# Affichage numéro 1333
# Affichage numéro 1334
# Affichage numéro 1335
# Affichage numéro 1336
# Affichage numéro 1337
# Affichage numéro 1338
# Affichage numéro 1339
# Affichage numéro 1340
# Affichage numéro 1341
# Affichage numéro 1342
# Affichage numéro 1343
# Affichage numéro 1344
# Affichage numéro 1345
# Affichage numéro 1346
# Affichage numéro 1347
# Affichage numéro 1348
# Affichage numéro 1349
# Affichage numéro 1350
# Affichage numéro 1351
# Affichage numéro 1352
# Affichage numéro 1353
# Affichage numéro 1354
# Affichage numéro 1355
# Affichage numéro 1356
# Affichage numéro 1357
# Affichage numéro 1358
# Affichage numéro 1359
# Affichage numéro 1360
# Affichage numéro 1361
# Affichage numéro 1362
# Affichage numéro 1363
# Affichage numéro 1364
# Affichage numéro 1365
# Affichage numéro 1366
# Affichage numéro 1367
# Affichage numéro 1368
# Affichage numéro 1369
# Affichage numéro 1370
# Affichage numéro 1371
# Affichage numéro 1372
# Affichage numéro 1373
# Affichage numéro 1374
# Affichage numéro 1375
# Affichage numéro 1376
# Affichage numéro 1377
# Affichage numéro 1378
# Affichage numéro 1379
# Affichage numéro 1380
# Affichage numéro 1381
# Affichage numéro 1382
# Affichage numéro 1383
# Affichage numéro 1384
# Affichage numéro 1385
# Affichage numéro 1386
# Affichage numéro 1387
# Affichage numéro 1388
# Affichage numéro 1389
# Affichage numéro 1390
# Affichage numéro 1391
# Affichage numéro 1392
# Affichage numéro 1393
# Affichage numéro 1394
# Affichage numéro 1395
# Affichage numéro 1396
# Affichage numéro 1397
# Affichage numéro 1398
# Affichage numéro 1399
# Affichage numéro 1400
# Affichage numéro 1401
# Affichage numéro 1402
# Affichage numéro 1403
# Affichage numéro 1404
# Affichage numéro 1405
# Affichage numéro 1406
# Affichage numéro 1407
# Affichage numéro 1408
# Affichage numéro 1409
# Affichage numéro 1410
# Affichage numéro 1411
# Affichage numéro 1412
# Affichage numéro 1413
# Affichage numéro 1414
# Affichage numéro 1415
# Affichage numéro 1416
# Affichage numéro 1417
# Affichage numéro 1418
# Affichage numéro 1419
# Affichage numéro 1420
# Affichage numéro 1421
# Affichage numéro 1422
# Affichage numéro 1423
# Affichage numéro 1424
# Affichage numéro 1425
# Affichage numéro 1426
# Affichage numéro 1427
# Affichage numéro 1428
# Affichage numéro 1429
# Affichage numéro 1430
# Affichage numéro 1431
# Affichage numéro 1432
# Affichage numéro 1433
# Affichage numéro 1434
# Affichage numéro 1435
# Affichage numéro 1436
# Affichage numéro 1437
# Affichage numéro 1438
# Affichage numéro 1439
# Affichage numéro 1440
# Affichage numéro 1441
# Affichage numéro 1442
# Affichage numéro 1443
# Affichage numéro 1444
# Affichage numéro 1445
# Affichage numéro 1446
# Affichage numéro 1447
# Affichage numéro 1448
# Affichage numéro 1449
# Affichage numéro 1450
# Affichage numéro 1451
# Affichage numéro 1452
# Affichage numéro 1453
# Affichage numéro 1454
# Affichage numéro 1455
# Affichage numéro 1456
# Affichage numéro 1457
# Affichage numéro 1458
# Affichage numéro 1459
# Affichage numéro 1460
# Affichage numéro 1461
# Affichage numéro 1462
# Affichage numéro 1463
# Affichage numéro 1464
# Affichage numéro 1465
# Affichage numéro 1466
# Affichage numéro 1467
# Affichage numéro 1468
# Affichage numéro 1469
# Affichage numéro 1470
# Affichage numéro 1471
# Affichage numéro 1472
# Affichage numéro 1473
# Affichage numéro 1474
# Affichage numéro 1475
# Affichage numéro 1476
# Affichage numéro 1477
# Affichage numéro 1478
# Affichage numéro 1479
# Affichage numéro 1480
# Affichage numéro 1481
# Affichage numéro 1482
# Affichage numéro 1483
# Affichage numéro 1484
# Affichage numéro 1485
# Affichage numéro 1486
# Affichage numéro 1487
# Affichage numéro 1488
# Affichage numéro 1489
# Affichage numéro 1490
# Affichage numéro 1491
# Affichage numéro 1492
# Affichage numéro 1493
# Affichage numéro 1494
# Affichage numéro 1495
# Affichage numéro 1496
# Affichage numéro 1497
# Affichage numéro 1498
# Affichage numéro 1499
# Affichage numéro 1500
# Affichage numéro 1501
# Affichage numéro 1502
# Affichage numéro 1503
# Affichage numéro 1504
# Affichage numéro 1505
# Affichage numéro 1506
# Affichage numéro 1507
# Affichage numéro 1508
# Affichage numéro 1509
# Affichage numéro 1510
# Affichage numéro 1511
# Affichage numéro 1512
# Affichage numéro 1513
# Affichage numéro 1514
# Affichage numéro 1515
# Affichage numéro 1516
# Affichage numéro 1517
# Affichage numéro 1518
# Affichage numéro 1519
# Affichage numéro 1520
# Affichage numéro 1521
# Affichage numéro 1522
# Affichage numéro 1523
# Affichage numéro 1524
# Affichage numéro 1525
# Affichage numéro 1526
# Affichage numéro 1527
# Affichage numéro 1528
# Affichage numéro 1529
# Affichage numéro 1530
# Affichage numéro 1531
# Affichage numéro 1532
# Affichage numéro 1533
# Affichage numéro 1534
# Affichage numéro 1535
# Affichage numéro 1536
# Affichage numéro 1537
# Affichage numéro 1538
# Affichage numéro 1539
# Affichage numéro 1540
# Affichage numéro 1541
# Affichage numéro 1542
# Affichage numéro 1543
# Affichage numéro 1544
# Affichage numéro 1545
# Affichage numéro 1546
# Affichage numéro 1547
# Affichage numéro 1548
# Affichage numéro 1549
# Affichage numéro 1550
# Affichage numéro 1551
# Affichage numéro 1552
# Affichage numéro 1553
# Affichage numéro 1554
# Affichage numéro 1555
# Affichage numéro 1556
# Affichage numéro 1557
# Affichage numéro 1558
# Affichage numéro 1559
# Affichage numéro 1560
# Affichage numéro 1561
# Affichage numéro 1562
# Affichage numéro 1563
# Affichage numéro 1564
# Affichage numéro 1565
# Affichage numéro 1566
# Affichage numéro 1567
# Affichage numéro 1568
# Affichage numéro 1569
# Affichage numéro 1570
# Affichage numéro 1571
# Affichage numéro 1572
# Affichage numéro 1573
# Affichage numéro 1574
# Affichage numéro 1575
# Affichage numéro 1576
# Affichage numéro 1577
# Affichage numéro 1578
# Affichage numéro 1579
# Affichage numéro 1580
# Affichage numéro 1581
# Affichage numéro 1582
# Affichage numéro 1583
# Affichage numéro 1584
# Affichage numéro 1585
# Affichage numéro 1586
# Affichage numéro 1587
# Affichage numéro 1588
# Affichage numéro 1589
# Affichage numéro 1590
# Affichage numéro 1591
# Affichage numéro 1592
# Affichage numéro 1593
# Affichage numéro 1594
# Affichage numéro 1595
# Affichage numéro 1596
# Affichage numéro 1597
# Affichage numéro 1598
# Affichage numéro 1599
# Affichage numéro 1600
# Affichage numéro 1601
# Affichage numéro 1602
# Affichage numéro 1603
# Affichage numéro 1604
# Affichage numéro 1605
# Affichage numéro 1606
# Affichage numéro 1607
# Affichage numéro 1608
# Affichage numéro 1609
# Affichage numéro 1610
# Affichage numéro 1611
# Affichage numéro 1612
# Affichage numéro 1613
# Affichage numéro 1614
# Affichage numéro 1615
# Affichage numéro 1616
# Affichage numéro 1617
# Affichage numéro 1618
# Affichage numéro 1619
# Affichage numéro 1620
# Affichage numéro 1621
# Affichage numéro 1622
# Affichage numéro 1623
# Affichage numéro 1624
# Affichage numéro 1625
# Affichage numéro 1626
# Affichage numéro 1627
# Affichage numéro 1628
# Affichage numéro 1629
# Affichage numéro 1630
# Affichage numéro 1631
# Affichage numéro 1632
# Affichage numéro 1633
# Affichage numéro 1634
# Affichage numéro 1635
# Affichage numéro 1636
# Affichage numéro 1637
# Affichage numéro 1638
# Affichage numéro 1639
# Affichage numéro 1640
# Affichage numéro 1641
# Affichage numéro 1642
# Affichage numéro 1643
# Affichage numéro 1644
# Affichage numéro 1645
# Affichage numéro 1646
# Affichage numéro 1647
# Affichage numéro 1648
# Affichage numéro 1649
# Affichage numéro 1650
# Affichage numéro 1651
# Affichage numéro 1652
# Affichage numéro 1653
# Affichage numéro 1654
# Affichage numéro 1655
# Affichage numéro 1656
# Affichage numéro 1657
# Affichage numéro 1658
# Affichage numéro 1659
# Affichage numéro 1660
# Affichage numéro 1661
# Affichage numéro 1662
# Affichage numéro 1663
# Affichage numéro 1664
# Affichage numéro 1665
# Affichage numéro 1666
# Affichage numéro 1667
# Affichage numéro 1668
# Affichage numéro 1669
# Affichage numéro 1670
# Affichage numéro 1671
# Affichage numéro 1672
# Affichage numéro 1673
# Affichage numéro 1674
# Affichage numéro 1675
# Affichage numéro 1676
# Affichage numéro 1677
# Affichage numéro 1678
# Affichage numéro 1679
# Affichage numéro 1680
# Affichage numéro 1681
# Affichage numéro 1682
# Affichage numéro 1683
# Affichage numéro 1684
# Affichage numéro 1685
# Affichage numéro 1686
# Affichage numéro 1687
# Affichage numéro 1688
# Affichage numéro 1689
# Affichage numéro 1690
# Affichage numéro 1691
# Affichage numéro 1692
# Affichage numéro 1693
# Affichage numéro 1694
# Affichage numéro 1695
# Affichage numéro 1696
# Affichage numéro 1697
# Affichage numéro 1698
# Affichage numéro 1699
# Affichage numéro 1700
# Affichage numéro 1701
# Affichage numéro 1702
# Affichage numéro 1703
# Affichage numéro 1704
# Affichage numéro 1705
# Affichage numéro 1706
# Affichage numéro 1707
# Affichage numéro 1708
# Affichage numéro 1709
# Affichage numéro 1710
# Affichage numéro 1711
# Affichage numéro 1712
# Affichage numéro 1713
# Affichage numéro 1714
# Affichage numéro 1715
# Affichage numéro 1716
# Affichage numéro 1717
# Affichage numéro 1718
# Affichage numéro 1719
# Affichage numéro 1720
# Affichage numéro 1721
# Affichage numéro 1722
# Affichage numéro 1723
# Affichage numéro 1724
# Affichage numéro 1725
# Affichage numéro 1726
# Affichage numéro 1727
# Affichage numéro 1728
# Affichage numéro 1729
# Affichage numéro 1730
# Affichage numéro 1731
# Affichage numéro 1732
# Affichage numéro 1733
# Affichage numéro 1734
# Affichage numéro 1735
# Affichage numéro 1736
# Affichage numéro 1737
# Affichage numéro 1738
# Affichage numéro 1739
# Affichage numéro 1740
# Affichage numéro 1741
# Affichage numéro 1742
# Affichage numéro 1743
# Affichage numéro 1744
# Affichage numéro 1745
# Affichage numéro 1746
# Affichage numéro 1747
# Affichage numéro 1748
# Affichage numéro 1749
# Affichage numéro 1750
# Affichage numéro 1751
# Affichage numéro 1752
# Affichage numéro 1753
# Affichage numéro 1754
# Affichage numéro 1755
# Affichage numéro 1756
# Affichage numéro 1757
# Affichage numéro 1758
# Affichage numéro 1759
# Affichage numéro 1760
# Affichage numéro 1761
# Affichage numéro 1762
# Affichage numéro 1763
# Affichage numéro 1764
# Affichage numéro 1765
# Affichage numéro 1766
# Affichage numéro 1767
# Affichage numéro 1768
# Affichage numéro 1769
# Affichage numéro 1770
# Affichage numéro 1771
# Affichage numéro 1772
# Affichage numéro 1773
# Affichage numéro 1774
# Affichage numéro 1775
# Affichage numéro 1776
# Affichage numéro 1777
# Affichage numéro 1778
# Affichage numéro 1779
# Affichage numéro 1780
# Affichage numéro 1781
# Affichage numéro 1782
# Affichage numéro 1783
# Affichage numéro 1784
# Affichage numéro 1785
# Affichage numéro 1786
# Affichage numéro 1787
# Affichage numéro 1788
# Affichage numéro 1789
# Affichage numéro 1790
# Affichage numéro 1791
# Affichage numéro 1792
# Affichage numéro 1793
# Affichage numéro 1794
# Affichage numéro 1795
# Affichage numéro 1796
# Affichage numéro 1797
# Affichage numéro 1798
# Affichage numéro 1799
# Affichage numéro 1800
# Affichage numéro 1801
# Affichage numéro 1802
# Affichage numéro 1803
# Affichage numéro 1804
# Affichage numéro 1805
# Affichage numéro 1806
# Affichage numéro 1807
# Affichage numéro 1808
# Affichage numéro 1809
# Affichage numéro 1810
# Affichage numéro 1811
# Affichage numéro 1812
# Affichage numéro 1813
# Affichage numéro 1814
# Affichage numéro 1815
# Affichage numéro 1816
# Affichage numéro 1817
# Affichage numéro 1818
# Affichage numéro 1819
# Affichage numéro 1820
# Affichage numéro 1821
# Affichage numéro 1822
# Affichage numéro 1823
# Affichage numéro 1824
# Affichage numéro 1825
# Affichage numéro 1826
# Affichage numéro 1827
# Affichage numéro 1828
# Affichage numéro 1829
# Affichage numéro 1830
# Affichage numéro 1831
# Affichage numéro 1832
# Affichage numéro 1833
# Affichage numéro 1834
# Affichage numéro 1835
# Affichage numéro 1836
# Affichage numéro 1837
# Affichage numéro 1838
# Affichage numéro 1839
# Affichage numéro 1840
# Affichage numéro 1841
# Affichage numéro 1842
# Affichage numéro 1843
# Affichage numéro 1844
# Affichage numéro 1845
# Affichage numéro 1846
# Affichage numéro 1847
# Affichage numéro 1848
# Affichage numéro 1849
# Affichage numéro 1850
# Affichage numéro 1851
# Affichage numéro 1852
# Affichage numéro 1853
# Affichage numéro 1854
# Affichage numéro 1855
# Affichage numéro 1856
# Affichage numéro 1857
# Affichage numéro 1858
# Affichage numéro 1859
# Affichage numéro 1860
# Affichage numéro 1861
# Affichage numéro 1862
# Affichage numéro 1863
# Affichage numéro 1864
# Affichage numéro 1865
# Affichage numéro 1866
# Affichage numéro 1867
# Affichage numéro 1868
# Affichage numéro 1869
# Affichage numéro 1870
# Affichage numéro 1871
# Affichage numéro 1872
# Affichage numéro 1873
# Affichage numéro 1874
# Affichage numéro 1875
# Affichage numéro 1876
# Affichage numéro 1877
# Affichage numéro 1878
# Affichage numéro 1879
# Affichage numéro 1880
# Affichage numéro 1881
# Affichage numéro 1882
# Affichage numéro 1883
# Affichage numéro 1884
# Affichage numéro 1885
# Affichage numéro 1886
# Affichage numéro 1887
# Affichage numéro 1888
# Affichage numéro 1889
# Affichage numéro 1890
# Affichage numéro 1891
# Affichage numéro 1892
# Affichage numéro 1893
# Affichage numéro 1894
# Affichage numéro 1895
# Affichage numéro 1896
# Affichage numéro 1897
# Affichage numéro 1898
# Affichage numéro 1899
# Affichage numéro 1900
# Affichage numéro 1901
# Affichage numéro 1902
# Affichage numéro 1903
# Affichage numéro 1904
# Affichage numéro 1905
# Affichage numéro 1906
# Affichage numéro 1907
# Affichage numéro 1908
# Affichage numéro 1909
# Affichage numéro 1910
# Affichage numéro 1911
# Affichage numéro 1912
# Affichage numéro 1913
# Affichage numéro 1914
# Affichage numéro 1915
# Affichage numéro 1916
# Affichage numéro 1917
# Affichage numéro 1918
# Affichage numéro 1919
# Affichage numéro 1920
# Affichage numéro 1921
# Affichage numéro 1922
# Affichage numéro 1923
# Affichage numéro 1924
# Affichage numéro 1925
# Affichage numéro 1926
# Affichage numéro 1927
# Affichage numéro 1928
# Affichage numéro 1929
# Affichage numéro 1930
# Affichage numéro 1931
# Affichage numéro 1932
# Affichage numéro 1933
# Affichage numéro 1934
# Affichage numéro 1935
# Affichage numéro 1936
# Affichage numéro 1937
# Affichage numéro 1938
# Affichage numéro 1939
# Affichage numéro 1940
# Affichage numéro 1941
# Affichage numéro 1942
# Affichage numéro 1943
# Affichage numéro 1944
# Affichage numéro 1945
# Affichage numéro 1946
# Affichage numéro 1947
# Affichage numéro 1948
# Affichage numéro 1949
# Affichage numéro 1950
# Affichage numéro 1951
# Affichage numéro 1952
# Affichage numéro 1953
# Affichage numéro 1954
# Affichage numéro 1955
# Affichage numéro 1956
# Affichage numéro 1957
# Affichage numéro 1958
# Affichage numéro 1959
# Affichage numéro 1960
# Affichage numéro 1961
# Affichage numéro 1962
# Affichage numéro 1963
# Affichage numéro 1964
# Affichage numéro 1965
# Affichage numéro 1966
# Affichage numéro 1967
# Affichage numéro 1968
# Affichage numéro 1969
# Affichage numéro 1970
# Affichage numéro 1971
# Affichage numéro 1972
# Affichage numéro 1973
# Affichage numéro 1974
# Affichage numéro 1975
# Affichage numéro 1976
# Affichage numéro 1977
# Affichage numéro 1978
# Affichage numéro 1979
# Affichage numéro 1980
# Affichage numéro 1981
# Affichage numéro 1982
# Affichage numéro 1983
# Affichage numéro 1984
# Affichage numéro 1985
# Affichage numéro 1986
# Affichage numéro 1987
# Affichage numéro 1988
# Affichage numéro 1989
# Affichage numéro 1990
# Affichage numéro 1991
# Affichage numéro 1992
# Affichage numéro 1993
# Affichage numéro 1994
# Affichage numéro 1995
# Affichage numéro 1996
# Affichage numéro 1997
# Affichage numéro 1998
# Affichage numéro 1999
# Affichage numéro 2000
# Affichage numéro 2001
# Affichage numéro 2002
# Affichage numéro 2003
# Affichage numéro 2004
# Affichage numéro 2005
# Affichage numéro 2006
# Affichage numéro 2007
# Affichage numéro 2008
# Affichage numéro 2009
# Affichage numéro 2010
# Affichage numéro 2011
# Affichage numéro 2012
# Affichage numéro 2013
# Affichage numéro 2014
# Affichage numéro 2015
# Affichage numéro 2016
# Affichage numéro 2017
# Affichage numéro 2018
# Affichage numéro 2019
# Affichage numéro 2020
# Affichage numéro 2021
# Affichage numéro 2022
# Affichage numéro 2023
# Affichage numéro 2024
# Affichage numéro 2025
# Affichage numéro 2026
# Affichage numéro 2027
# Affichage numéro 2028
# Affichage numéro 2029
# Affichage numéro 2030
# Affichage numéro 2031
# Affichage numéro 2032
# Affichage numéro 2033
# Affichage numéro 2034
# Affichage numéro 2035
# Affichage numéro 2036
# Affichage numéro 2037
# Affichage numéro 2038
# Affichage numéro 2039
# Affichage numéro 2040
# Affichage numéro 2041
# Affichage numéro 2042
# Affichage numéro 2043
# Affichage numéro 2044
# Affichage numéro 2045
# Affichage numéro 2046
# Affichage numéro 2047
# Affichage numéro 2048
# Affichage numéro 2049
# Affichage numéro 2050
# Affichage numéro 2051
# Affichage numéro 2052
# Affichage numéro 2053
# Affichage numéro 2054
# Affichage numéro 2055
# Affichage numéro 2056
# Affichage numéro 2057
# Affichage numéro 2058
# Affichage numéro 2059
# Affichage numéro 2060
# Affichage numéro 2061
# Affichage numéro 2062
# Affichage numéro 2063
# Affichage numéro 2064
# Affichage numéro 2065
# Affichage numéro 2066
# Affichage numéro 2067
# Affichage numéro 2068
# Affichage numéro 2069
# Affichage numéro 2070
# Affichage numéro 2071
# Affichage numéro 2072
# Affichage numéro 2073
# Affichage numéro 2074
# Affichage numéro 2075
# Affichage numéro 2076
# Affichage numéro 2077
# Affichage numéro 2078
# Affichage numéro 2079
# Affichage numéro 2080
# Affichage numéro 2081
# Affichage numéro 2082
# Affichage numéro 2083
# Affichage numéro 2084
# Affichage numéro 2085
# Affichage numéro 2086
# Affichage numéro 2087
# Affichage numéro 2088
# Affichage numéro 2089
# Affichage numéro 2090
# Affichage numéro 2091
# Affichage numéro 2092
# Affichage numéro 2093
# Affichage numéro 2094
# Affichage numéro 2095
# Affichage numéro 2096
# Affichage numéro 2097
# Affichage numéro 2098
# Affichage numéro 2099
# Affichage numéro 2100
# Affichage numéro 2101
# Affichage numéro 2102
# Affichage numéro 2103
# Affichage numéro 2104
# Affichage numéro 2105
# Affichage numéro 2106
# Affichage numéro 2107
# Affichage numéro 2108
# Affichage numéro 2109
# Affichage numéro 2110
# Affichage numéro 2111
# Affichage numéro 2112
# Affichage numéro 2113
# Affichage numéro 2114
# Affichage numéro 2115
# Affichage numéro 2116
# Affichage numéro 2117
# Affichage numéro 2118
# Affichage numéro 2119
# Affichage numéro 2120
# Affichage numéro 2121
# Affichage numéro 2122
# Affichage numéro 2123
# Affichage numéro 2124
# Affichage numéro 2125
# Affichage numéro 2126
# Affichage numéro 2127
# Affichage numéro 2128
# Affichage numéro 2129
# Affichage numéro 2130
# Affichage numéro 2131
# Affichage numéro 2132
# Affichage numéro 2133
# Affichage numéro 2134
# Affichage numéro 2135
# Affichage numéro 2136
# Affichage numéro 2137
# Affichage numéro 2138
# Affichage numéro 2139
# Affichage numéro 2140
# Affichage numéro 2141
# Affichage numéro 2142
# Affichage numéro 2143
# Affichage numéro 2144
# Affichage numéro 2145
# Affichage numéro 2146
# Affichage numéro 2147
# Affichage numéro 2148
# Affichage numéro 2149
# Affichage numéro 2150
# Affichage numéro 2151
# Affichage numéro 2152
# Affichage numéro 2153
# Affichage numéro 2154
# Affichage numéro 2155
# Affichage numéro 2156
# Affichage numéro 2157
# Affichage numéro 2158
# Affichage numéro 2159
# Affichage numéro 2160
# Affichage numéro 2161
# Affichage numéro 2162
# Affichage numéro 2163
# Affichage numéro 2164
# Affichage numéro 2165
# Affichage numéro 2166
# Affichage numéro 2167
# Affichage numéro 2168
# Affichage numéro 2169
# Affichage numéro 2170
# Affichage numéro 2171
# Affichage numéro 2172
# Affichage numéro 2173
# Affichage numéro 2174
# Affichage numéro 2175
# Affichage numéro 2176
# Affichage numéro 2177
# Affichage numéro 2178
# Affichage numéro 2179
# Affichage numéro 2180
# Affichage numéro 2181
# Affichage numéro 2182
# Affichage numéro 2183
# Affichage numéro 2184
# Affichage numéro 2185
# Affichage numéro 2186
# Affichage numéro 2187
# Affichage numéro 2188
# Affichage numéro 2189
# Affichage numéro 2190
# Affichage numéro 2191
# Affichage numéro 2192
# Affichage numéro 2193
# Affichage numéro 2194
# Affichage numéro 2195
# Affichage numéro 2196
# Affichage numéro 2197
# Affichage numéro 2198
# Affichage numéro 2199
# Affichage numéro 2200
# Affichage numéro 2201
# Affichage numéro 2202
# Affichage numéro 2203
# Affichage numéro 2204
# Affichage numéro 2205
# Affichage numéro 2206
# Affichage numéro 2207
# Affichage numéro 2208
# Affichage numéro 2209
# Affichage numéro 2210
# Affichage numéro 2211
# Affichage numéro 2212
# Affichage numéro 2213
# Affichage numéro 2214
# Affichage numéro 2215
# Affichage numéro 2216
# Affichage numéro 2217
# Affichage numéro 2218
# Affichage numéro 2219
# Affichage numéro 2220
# Affichage numéro 2221
# Affichage numéro 2222
# Affichage numéro 2223
# Affichage numéro 2224
# Affichage numéro 2225
# Affichage numéro 2226
# Affichage numéro 2227
# Affichage numéro 2228
# Affichage numéro 2229
# Affichage numéro 2230
# Affichage numéro 2231
# Affichage numéro 2232
# ...
# Affichage numéro 6340
# Affichage numéro 6341
# Affichage numéro 6342
# Affichage numéro 6343
# Affichage numéro 6344
# Affichage numéro 6345
# Affichage numéro 6346
# Affichage numéro 6347
# Affichage numéro 6348
# Affichage numéro 6349
# Affichage numéro 6350
# Affichage numéro 6351
# Affichage numéro 6352
# Affichage numéro 6353
# Affichage numéro 6354
# Affichage numéro 6355
# Affichage numéro 6356
# Affichage numéro 6357
# Affichage numéro 6358
# Affichage numéro 6359
# Affichage numéro 6360
# Affichage numéro 6361
# Affichage numéro 6362
# Affichage numéro 6363
# Affichage numéro 6364
# Affichage numéro 6365
# Affichage numéro 6366
# Affichage numéro 6367
# Affichage numéro 6368
# Affichage numéro 6369
# Affichage numéro 6370
# Affichage numéro 6371
# Affichage numéro 6372
# Affichage numéro 6373
# Affichage numéro 6374
# Affichage numéro 6375
# Affichage numéro 6376
# Affichage numéro 6377
# Affichage numéro 6378
# Affichage numéro 6379
# Affichage numéro 6380
# Affichage numéro 6381
# Affichage numéro 6382
# Affichage numéro 6383
# Affichage numéro 6384
# Affichage numéro 6385
# Affichage numéro 6386
# Affichage numéro 6387
# Affichage numéro 6388
# Affichage numéro 6389
# Affichage numéro 6390
# Affichage numéro 6391
# Affichage numéro 6392
# Affichage numéro 6393
# Affichage numéro 6394
# Affichage numéro 6395
# Affichage numéro 6396
# Affichage numéro 6397
# Affichage numéro 6398
# Affichage numéro 6399
# Affichage numéro 6400
# Affichage numéro 6401
# Affichage numéro 6402
# Affichage numéro 6403
# Affichage numéro 6404
# Affichage numéro 6405
# Affichage numéro 6406
# Affichage numéro 6407
# Affichage numéro 6408
# Affichage numéro 6409
# Affichage numéro 6410
# Affichage numéro 6411
# Affichage numéro 6412
# Affichage numéro 6413
# Affichage numéro 6414
# Affichage numéro 6415
# Affichage numéro 6416
# Affichage numéro 6417
# Affichage numéro 6418
# Affichage numéro 6419
# Affichage numéro 6420
# Affichage numéro 6421
# Affichage numéro 6422
# Affichage numéro 6423
# Affichage numéro 6424
# Affichage numéro 6425
# Affichage numéro 6426
# Affichage numéro 6427
# Affichage numéro 6428
# Affichage numéro 6429
# Affichage numéro 6430
# Affichage numéro 6431
# Affichage numéro 6432
# Affichage numéro 6433
# Affichage numéro 6434
# Affichage numéro 6435
# Affichage numéro 6436
# Affichage numéro 6437
# Affichage numéro 6438
# Affichage numéro 6439
# Affichage numéro 6440
# Affichage numéro 6441
# Affichage numéro 6442
# Affichage numéro 6443
# Affichage numéro 6444
# Affichage numéro 6445
# Affichage numéro 6446
# Affichage numéro 6447
# Affichage numéro 6448
# Affichage numéro 6449
# Affichage numéro 6450
# Affichage numéro 6451
# Affichage numéro 6452
# Affichage numéro 6453
# Affichage numéro 6454
# Affichage numéro 6455
# Affichage numéro 6456
# Affichage numéro 6457
# Affichage numéro 6458
# Affichage numéro 6459
# Affichage numéro 6460
# Affichage numéro 6461
# Affichage numéro 6462
# Affichage numéro 6463
# Affichage numéro 6464
# Affichage numéro 6465
# Affichage numéro 6466
# Affichage numéro 6467
# Affichage numéro 6468
# Affichage numéro 6469
# Affichage numéro 6470
# Affichage numéro 6471
# Affichage numéro 6472
# Affichage numéro 6473
# Affichage numéro 6474
# Affichage numéro 6475
# Affichage numéro 6476
# Affichage numéro 6477
# Affichage numéro 6478
# Affichage numéro 6479
# Affichage numéro 6480
# Affichage numéro 6481
# Affichage numéro 6482
# Affichage numéro 6483
# Affichage numéro 6484
# Affichage numéro 6485
# Affichage numéro 6486
# Affichage numéro 6487
# Affichage numéro 6488
# Affichage numéro 6489
# Affichage numéro 6490
# Affichage numéro 6491
# Affichage numéro 6492
# Affichage numéro 6493
# Affichage numéro 6494
# Affichage numéro 6495
# Affichage numéro 6496
# Affichage numéro 6497
# Affichage numéro 6498
# Affichage numéro 6499
# Affichage numéro 6500
# Affichage numéro 6501
# Affichage numéro 6502
# Affichage numéro 6503
# Affichage numéro 6504
# Affichage numéro 6505
# Affichage numéro 6506
# Affichage numéro 6507
# Affichage numéro 6508
# Affichage numéro 6509
# Affichage numéro 6510
# Affichage numéro 6511
# Affichage numéro 6512
# Affichage numéro 6513
# Affichage numéro 6514
# Affichage numéro 6515
# Affichage numéro 6516
# Affichage numéro 6517
# Affichage numéro 6518
# Affichage numéro 6519
# Affichage numéro 6520
# Affichage numéro 6521
# Affichage numéro 6522
# Affichage numéro 6523
# Affichage numéro 6524
# Affichage numéro 6525
# Affichage numéro 6526
# Affichage numéro 6527
# Affichage numéro 6528
# Affichage numéro 6529
# Affichage numéro 6530
# Affichage numéro 6531
# Affichage numéro 6532
# Affichage numéro 6533
# Affichage numéro 6534
# Affichage numéro 6535
# Affichage numéro 6536
# Affichage numéro 6537
# Affichage numéro 6538
# Affichage numéro 6539
# Affichage numéro 6540
# Affichage numéro 6541
# Affichage numéro 6542
# Affichage numéro 6543
# Affichage numéro 6544
# Affichage numéro 6545
# Affichage numéro 6546
# Affichage numéro 6547
# Affichage numéro 6548
# Affichage numéro 6549
# Affichage numéro 6550
# Affichage numéro 6551
# Affichage numéro 6552
# Affichage numéro 6553
# Affichage numéro 6554
# Affichage numéro 6555
# Affichage numéro 6556
# Affichage numéro 6557
# Affichage numéro 6558
# Affichage numéro 6559
# Affichage numéro 6560
# Affichage numéro 6561
# Affichage numéro 6562
# Affichage numéro 6563
# Affichage numéro 6564
# Affichage numéro 6565
# Affichage numéro 6566
# Affichage numéro 6567
# Affichage numéro 6568
# Affichage numéro 6569
# Affichage numéro 6570
# Affichage numéro 6571
# Affichage numéro 6572
# Affichage numéro 6573
# Affichage numéro 6574
# Affichage numéro 6575
# Affichage numéro 6576
# Affichage numéro 6577
# Affichage numéro 6578
# Affichage numéro 6579
# Affichage numéro 6580
# Affichage numéro 6581
# Affichage numéro 6582
# Affichage numéro 6583
# Affichage numéro 6584
# Affichage numéro 6585
# Affichage numéro 6586
# Affichage numéro 6587
# Affichage numéro 6588
# Affichage numéro 6589
# Affichage numéro 6590
# Affichage numéro 6591
# Affichage numéro 6592
# Affichage numéro 6593
# Affichage numéro 6594
# Affichage numéro 6595
# Affichage numéro 6596
# Affichage numéro 6597
# Affichage numéro 6598
# Affichage numéro 6599
# Affichage numéro 6600
# Affichage numéro 6601
# Affichage numéro 6602
# Affichage numéro 6603
# Affichage numéro 6604
# Affichage numéro 6605
# Affichage numéro 6606
# Affichage numéro 6607
# Affichage numéro 6608
# Affichage numéro 6609
# Affichage numéro 6610
# Affichage numéro 6611
# Affichage numéro 6612
# Affichage numéro 6613
# Affichage numéro 6614
# Affichage numéro 6615
# Affichage numéro 6616
# Affichage numéro 6617
# Affichage numéro 6618
# Affichage numéro 6619
# Affichage numéro 6620
# Affichage numéro 6621
# Affichage numéro 6622
# Affichage numéro 6623
# Affichage numéro 6624
# Affichage numéro 6625
# Affichage numéro 6626
# Affichage numéro 6627
# Affichage numéro 6628
# Affichage numéro 6629
# Affichage numéro 6630
# Affichage numéro 6631
# Affichage numéro 6632
# Affichage numéro 6633
# Affichage numéro 6634
# Affichage numéro 6635
# Affichage numéro 6636
# Affichage numéro 6637
# Affichage numéro 6638
# Affichage numéro 6639
# Affichage numéro 6640
# Affichage numéro 6641
# Affichage numéro 6642
# Affichage numéro 6643
# Affichage numéro 6644
# Affichage numéro 6645
# Affichage numéro 6646
# Affichage numéro 6647
# Affichage numéro 6648
# Affichage numéro 6649
# Affichage numéro 6650
# Affichage numéro 6651
# Affichage numéro 6652
# Affichage numéro 6653
# Affichage numéro 6654
# Affichage numéro 6655
# Affichage numéro 6656
# Affichage numéro 6657
# Affichage numéro 6658
# Affichage numéro 6659
# Affichage numéro 6660
# Affichage numéro 6661
# Affichage numéro 6662
# Affichage numéro 6663
# Affichage numéro 6664
# Affichage numéro 6665
# Affichage numéro 6666
# Affichage numéro 6667
# Affichage numéro 6668
# Affichage numéro 6669
# Affichage numéro 6670
# Affichage numéro 6671
# Affichage numéro 6672
# Affichage numéro 6673
# Affichage numéro 6674
# Affichage numéro 6675
# Affichage numéro 6676
# Affichage numéro 6677
# Affichage numéro 6678
# Affichage numéro 6679
# Affichage numéro 6680
# Affichage numéro 6681
# Affichage numéro 6682
# Affichage numéro 6683
# Affichage numéro 6684
# Affichage numéro 6685
# Affichage numéro 6686
# Affichage numéro 6687
# Affichage numéro 6688
# Affichage numéro 6689
# Affichage numéro 6690
# Affichage numéro 6691
# Affichage numéro 6692
# Affichage numéro 6693
# Affichage numéro 6694
# Affichage numéro 6695
# Affichage numéro 6696
# Affichage numéro 6697
# Affichage numéro 6698
# Affichage numéro 6699
# Affichage numéro 6700
# Affichage numéro 6701
# Affichage numéro 6702
# Affichage numéro 6703
# Affichage numéro 6704
# Affichage numéro 6705
# Affichage numéro 6706
# Affichage numéro 6707
# Affichage numéro 6708
# Affichage numéro 6709
# Affichage numéro 6710
# Affichage numéro 6711
# Affichage numéro 6712
# Affichage numéro 6713
# Affichage numéro 6714
# Affichage numéro 6715
# Affichage numéro 6716
# Affichage numéro 6717
# Affichage numéro 6718
# Affichage numéro 6719
# Affichage numéro 6720
# Affichage numéro 6721
# Affichage numéro 6722
# Affichage numéro 6723
# Affichage numéro 6724
# Affichage numéro 6725
# Affichage numéro 6726
# Affichage numéro 6727
# Affichage numéro 6728
# Affichage numéro 6729
# Affichage numéro 6730
# Affichage numéro 6731
# Affichage numéro 6732
# Affichage numéro 6733
# Affichage numéro 6734
# Affichage numéro 6735
# Affichage numéro 6736
# Affichage numéro 6737
# Affichage numéro 6738
# Affichage numéro 6739
# Affichage numéro 6740
# Affichage numéro 6741
# Affichage numéro 6742
# Affichage numéro 6743
# Affichage numéro 6744
# Affichage numéro 6745
# Affichage numéro 6746
# Affichage numéro 6747
# Affichage numéro 6748
# Affichage numéro 6749
# Affichage numéro 6750
# Affichage numéro 6751
# Affichage numéro 6752
# Affichage numéro 6753
# Affichage numéro 6754
# Affichage numéro 6755
# Affichage numéro 6756
# Affichage numéro 6757
# Affichage numéro 6758
# Affichage numéro 6759
# Affichage numéro 6760
# Affichage numéro 6761
# Affichage numéro 6762
# Affichage numéro 6763
# Affichage numéro 6764
# Affichage numéro 6765
# Affichage numéro 6766
# Affichage numéro 6767
# Affichage numéro 6768
# Affichage numéro 6769
# Affichage numéro 6770
# Affichage numéro 6771
# Affichage numéro 6772
# Affichage numéro 6773
# Affichage numéro 6774
# Affichage numéro 6775
# Affichage numéro 6776
# Affichage numéro 6777
# Affichage numéro 6778
# Affichage numéro 6779
# Affichage numéro 6780
# Affichage numéro 6781
# Affichage numéro 6782
# Affichage numéro 6783
# Affichage numéro 6784
# Affichage numéro 6785
# Affichage numéro 6786
# Affichage numéro 6787
# Affichage numéro 6788
# Affichage numéro 6789
# Affichage numéro 6790
# Affichage numéro 6791
# Affichage numéro 6792
# Affichage numéro 6793
# Affichage numéro 6794
# Affichage numéro 6795
# Affichage numéro 6796
# Affichage numéro 6797
# Affichage numéro 6798
# Affichage numéro 6799
# Affichage numéro 6800
# Affichage numéro 6801
# Affichage numéro 6802
# Affichage numéro 6803
# Affichage numéro 6804
# Affichage numéro 6805
# Affichage numéro 6806
# Affichage numéro 6807
# Affichage numéro 6808
# Affichage numéro 6809
# Affichage numéro 6810
# Affichage numéro 6811
# Affichage numéro 6812
# Affichage numéro 6813
# Affichage numéro 6814
# Affichage numéro 6815
# Affichage numéro 6816
# Affichage numéro 6817
# Affichage numéro 6818
# Affichage numéro 6819
# Affichage numéro 6820
# Affichage numéro 6821
# Affichage numéro 6822
# Affichage numéro 6823
# Affichage numéro 6824
# Affichage numéro 6825
# Affichage numéro 6826
# Affichage numéro 6827
# Affichage numéro 6828
# Affichage numéro 6829
# Affichage numéro 6830
# Affichage numéro 6831
# Affichage numéro 6832
# Affichage numéro 6833
# Affichage numéro 6834
# Affichage numéro 6835
# Affichage numéro 6836
# Affichage numéro 6837
# Affichage numéro 6838
# Affichage numéro 6839
# Affichage numéro 6840
# Affichage numéro 6841
# Affichage numéro 6842
# Affichage numéro 6843
# Affichage numéro 6844
# Affichage numéro 6845
# Affichage numéro 6846
# Affichage numéro 6847
# Affichage numéro 6848
# Affichage numéro 6849
# Affichage numéro 6850
# Affichage numéro 6851
# Affichage numéro 6852
# Affichage numéro 6853
# Affichage numéro 6854
# Affichage numéro 6855
# Affichage numéro 6856
# Affichage numéro 6857
# Affichage numéro 6858
# Affichage numéro 6859
# Affichage numéro 6860
# Affichage numéro 6861
# Affichage numéro 6862
# Affichage numéro 6863
# Affichage numéro 6864
# Affichage numéro 6865
# Affichage numéro 6866
# Affichage numéro 6867
# Affichage numéro 6868
# Affichage numéro 6869
# Affichage numéro 6870
# Affichage numéro 6871
# Affichage numéro 6872
# Affichage numéro 6873
# Affichage numéro 6874
# Affichage numéro 6875
# Affichage numéro 6876
# Affichage numéro 6877
# Affichage numéro 6878
# Affichage numéro 6879
# Affichage numéro 6880
# Affichage numéro 6881
# Affichage numéro 6882
# Affichage numéro 6883
# Affichage numéro 6884
# Affichage numéro 6885
# Affichage numéro 6886
# Affichage numéro 6887
# Affichage numéro 6888
# Affichage numéro 6889
# Affichage numéro 6890
# Affichage numéro 6891
# Affichage numéro 6892
# Affichage numéro 6893
# Affichage numéro 6894
# Affichage numéro 6895
# Affichage numéro 6896
# Affichage numéro 6897
# Affichage numéro 6898
# Affichage numéro 6899
# Affichage numéro 6900
# Affichage numéro 6901
# Affichage numéro 6902
# Affichage numéro 6903
# Affichage numéro 6904
# Affichage numéro 6905
# Affichage numéro 6906
# Affichage numéro 6907
# Affichage numéro 6908
# Affichage numéro 6909
# Affichage numéro 6910
# Affichage numéro 6911
# Affichage numéro 6912
# Affichage numéro 6913
# Affichage numéro 6914
# Affichage numéro 6915
# Affichage numéro 6916
# Affichage numéro 6917
# Affichage numéro 6918
# Affichage numéro 6919
# Affichage numéro 6920
# Affichage numéro 6921
# Affichage numéro 6922
# Affichage numéro 6923
# Affichage numéro 6924
# Affichage numéro 6925
# Affichage numéro 6926
# Affichage numéro 6927
# Affichage numéro 6928
# Affichage numéro 6929
# Affichage numéro 6930
# Affichage numéro 6931
# Affichage numéro 6932
# Affichage numéro 6933
# Affichage numéro 6934
# Affichage numéro 6935
# Affichage numéro 6936
# Affichage numéro 6937
# Affichage numéro 6938
# Affichage numéro 6939
# Affichage numéro 6940
# Affichage numéro 6941
# Affichage numéro 6942
# Affichage numéro 6943
# Affichage numéro 6944
# Affichage numéro 6945
# Affichage numéro 6946
# Affichage numéro 6947
# Affichage numéro 6948
# Affichage numéro 6949
# Affichage numéro 6950
# Affichage numéro 6951
# Affichage numéro 6952
# Affichage numéro 6953
# Affichage numéro 6954
# Affichage numéro 6955
# Affichage numéro 6956
# Affichage numéro 6957
# Affichage numéro 6958
# Affichage numéro 6959
# Affichage numéro 6960
# Affichage numéro 6961
# Affichage numéro 6962
# Affichage numéro 6963
# Affichage numéro 6964
# Affichage numéro 6965
# Affichage numéro 6966
# Affichage numéro 6967
# Affichage numéro 6968
# Affichage numéro 6969
# Affichage numéro 6970
# Affichage numéro 6971
# Affichage numéro 6972
# Affichage numéro 6973
# Affichage numéro 6974
# Affichage numéro 6975
# Affichage numéro 6976
# Affichage numéro 6977
# Affichage numéro 6978
# Affichage numéro 6979
# Affichage numéro 6980
# Affichage numéro 6981
# Affichage numéro 6982
# Affichage numéro 6983
# Affichage numéro 6984
# Affichage numéro 6985
# Affichage numéro 6986
# Affichage numéro 6987
# Affichage numéro 6988
# Affichage numéro 6989
# Affichage numéro 6990
# Affichage numéro 6991
# Affichage numéro 6992
# Affichage numéro 6993
# Affichage numéro 6994
# Affichage numéro 6995
# Affichage numéro 6996
# Affichage numéro 6997
# Affichage numéro 6998
# Affichage numéro 6999
# Affichage numéro 7000
# Affichage numéro 7001
# Affichage numéro 7002
# Affichage numéro 7003
# Affichage numéro 7004
# Affichage numéro 7005
# Affichage numéro 7006
# Affichage numéro 7007
# Affichage numéro 7008
# Affichage numéro 7009
# Affichage numéro 7010
# Affichage numéro 7011
# Affichage numéro 7012
# Affichage numéro 7013
# Affichage numéro 7014
# Affichage numéro 7015
# Affichage numéro 7016
# Affichage numéro 7017
# Affichage numéro 7018
# Affichage numéro 7019
# Affichage numéro 7020
# Affichage numéro 7021
# Affichage numéro 7022
# Affichage numéro 7023
# Affichage numéro 7024
# Affichage numéro 7025
# Affichage numéro 7026
# Affichage numéro 7027
# Affichage numéro 7028
# Affichage numéro 7029
# Affichage numéro 7030
# Affichage numéro 7031
# Affichage numéro 7032
# Affichage numéro 7033
# Affichage numéro 7034
# Affichage numéro 7035
# Affichage numéro 7036
# Affichage numéro 7037
# Affichage numéro 7038
# Affichage numéro 7039
# Affichage numéro 7040
# Affichage numéro 7041
# Affichage numéro 7042
# Affichage numéro 7043
# Affichage numéro 7044
# Affichage numéro 7045
# Affichage numéro 7046
# Affichage numéro 7047
# Affichage numéro 7048
# Affichage numéro 7049
# Affichage numéro 7050
# Affichage numéro 7051
# Affichage numéro 7052
# Affichage numéro 7053
# Affichage numéro 7054
# Affichage numéro 7055
# Affichage numéro 7056
# Affichage numéro 7057
# Affichage numéro 7058
# Affichage numéro 7059
# Affichage numéro 7060
# Affichage numéro 7061
# Affichage numéro 7062
# Affichage numéro 7063
# Affichage numéro 7064
# Affichage numéro 7065
# Affichage numéro 7066

# %% [markdown]
# **Déplacer une balle**
#
# ---
# Modifier le programme suivant pour que la balle se déplace toute seule.

# %%
import tkinter as tk

HEIGHT = 600
WIDTH = 800

def bouge_cercle():
    canvas.move(cercle, 50, 50) # méthode qui déplace l'objet cercle

    bouton.after(100,bouge_cercle)

racine = tk.Tk() # Création de la fenêtre racine
bouton = tk.Button(text="déplace cercle", 
                    command=bouge_cercle, font = ("Helvetica", "30")
                  )
bouton.grid(column=0, row=1)
canvas = tk.Canvas(racine, bg="red", height=HEIGHT, width=WIDTH)
canvas.grid(column=0, row=0)
# on récupère l'identifiant du cercle:
cercle = canvas.create_oval((100, 100), (300, 300), fill="blue", width=5, outline="cyan") 
racine.mainloop() # Lancement de la boucle principale

# %%
import tkinter as tk

HEIGHT = 500
WIDTH = 500

def bouge_cercle():
    canvas.move(cercle, 10, 10) # méthode qui déplace l'objet cercle
    canvas.after(200, bouge_cercle)
    
racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=HEIGHT, width=WIDTH)
canvas.grid(column=0, row=0)
cercle = canvas.create_oval((100, 100), (300, 300), fill="blue", width=5, outline="cyan") 
bouge_cercle()
racine.mainloop() # Lancement de la boucle principale
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/l1-python/lib/python3.9/tkinter/__init__.py", line 1889, in __call__
#     try:
# KeyboardInterrupt

# %% [markdown]
# ## 6. Autres méthodes associées au widget canvas

# %% [markdown]
# **Méthode `.coords()`**
#
# ---
# ```python
# canvas.coords(objet)
# ```
# retourne les coordonnées de l'objet, en général celle de la boîte englobante, sous la forme d'un tuple $(x_1, y_1, x_2, y_2)$
#
# ```python
# canvas.coords(objet, x1, y1, x2, y2)
# ```
# modifie les coordonnées de l'objet.

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=500, width=500)
canvas.grid(column=0, row=0)
cercle = canvas.create_oval((100, 100), (300, 300), fill="blue", width=5, outline="cyan") 
print(canvas.coords(cercle))
canvas.coords(cercle, 300, 300, 500, 500) 
print(canvas.coords(cercle))
racine.mainloop() # Lancement de la boucle principale
# Out:
# [100.0, 100.0, 300.0, 300.0]
# [300.0, 300.0, 500.0, 500.0]

# %% [markdown]
# **Méthode `.itemconfigure()`**
#
# ---
# ```python
# canvas.itemconfigure(objet, param=new_value)
# ```
# modifie le paramètre `param` de l'objet passé en argument.

# %%
import tkinter as tk

racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=500, width=500)
canvas.grid(column=0, row=0)
cercle = canvas.create_oval((100, 100), (300, 300), fill="blue", width=5, outline="cyan") 
canvas.itemconfigure(cercle, fill="white") 
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Méthode `.delete()`**
#
# ---
# Permet de supprimer un objet graphique à partir de son identifiant.

# %%
import tkinter as tk
  
cpt = 0

def dessine_efface():
    global cpt, cercle
    cpt = 1 - cpt # vaut alternativement 0 et 1
    if cpt == 0:
        cercle = canvas.create_oval((100, 100), (400, 400), fill="blue", width=5, outline="cyan") 
    else:
        canvas.delete(cercle)
    canvas.after(1000, dessine_efface)
        
    
racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=500, width=500)
canvas.grid(column=0, row=0)
cercle = canvas.create_oval((100, 100), (400, 400), fill="blue", width=5, outline="cyan") 
dessine_efface()
racine.mainloop() # Lancement de la boucle principale

# %% [markdown]
# **Méthode `find_closest`**
#
# ---
# ```python
# canvas.find_closest(x, y)
# ```
# Retourne une liste contenant l'identifiant des objets les plus proches du point $(x, y)$. En première position se trouve l'objet au-dessus des autres.

# %%
import tkinter as tk
  
def efface_objet_proche(event):
    objet = canvas.find_closest(event.x, event.y)
    if len(objet) != 0:
        canvas.delete(objet[0])
    
racine = tk.Tk() # Création de la fenêtre racine
canvas = tk.Canvas(racine, bg="red", height=500, width=500)
canvas.grid(column=0, row=0)
cercle = canvas.create_oval((100, 100), (200, 200), fill="blue") 
carre = canvas.create_rectangle((300, 300), (400, 400), fill="yellow") 
canvas.bind("<Button-1>", efface_objet_proche)
racine.mainloop() # Lancement de la boucle principale
